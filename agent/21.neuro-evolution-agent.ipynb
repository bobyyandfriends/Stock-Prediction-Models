# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            fitnesses = [i.fitness for i in self.population]
            sort_fitness = np.argsort(fitnesses)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(50)
# Out:
# epoch 5, fittest individual 0 with accuracy 11.279050
# epoch 10, fittest individual 0 with accuracy 18.611598
# epoch 15, fittest individual 0 with accuracy 18.611598
# epoch 20, fittest individual 0 with accuracy 18.611598
# epoch 25, fittest individual 0 with accuracy 18.611598
# epoch 30, fittest individual 0 with accuracy 18.611598
# epoch 35, fittest individual 0 with accuracy 18.611598
# epoch 40, fittest individual 0 with accuracy 18.611598
# epoch 45, fittest individual 0 with accuracy 18.611598
# epoch 50, fittest individual 0 with accuracy 18.611598

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2, sell 1 unit at price 762.020020, investment -0.014431 %, total balance 9999.890015,
# day 6: buy 1 unit at price 762.559998, total balance 9237.330017
# day 7: buy 1 unit at price 754.020020, total balance 8483.309997
# day 9, sell 1 unit at price 758.489990, investment -0.533730 %, total balance 9241.799987,
# day 10, sell 1 unit at price 764.479980, investment 1.387226 %, total balance 10006.279967,
# day 12: buy 1 unit at price 760.539978, total balance 9245.739989
# day 13: buy 1 unit at price 769.200012, total balance 8476.539977
# day 14, sell 1 unit at price 768.270020, investment 1.016389 %, total balance 9244.809997,
# day 15, sell 1 unit at price 760.989990, investment -1.067346 %, total balance 10005.799987,
# day 18: buy 1 unit at price 770.840027, total balance 9234.959960
# day 19, sell 1 unit at price 758.039978, investment -1.660532 %, total balance 9992.999938,
# day 20: buy 1 unit at price 747.919983, total balance 9245.079955
# day 21, sell 1 unit at price 750.500000, investment 0.344959 %, total balance 9995.579955,
# day 22: buy 1 unit at price 762.520020, total balance 9233.059935
# day 23: buy 1 unit at price 759.109985, total balance 8473.949950
# day 24: buy 1 unit at price 771.190002, total balance 7702.759948
# day 25: buy 1 unit at price 776.419983, total balance 6926.339965
# day 27, sell 1 unit at price 789.270020, investment 3.508105 %, total balance 7715.609985,
# day 28, sell 1 unit at price 796.099976, investment 4.872810 %, total balance 8511.709961,
# day 29, sell 1 unit at price 797.070007, investment 3.355853 %, total balance 9308.779968,
# day 30: buy 1 unit at price 797.849976, total balance 8510.929992
# day 31, sell 1 unit at price 790.799988, investment 1.852091 %, total balance 9301.729980,
# day 32, sell 1 unit at price 794.200012, investment -0.457475 %, total balance 10095.929992,
# day 34: buy 1 unit at price 794.559998, total balance 9301.369994
# day 35: buy 1 unit at price 791.260010, total balance 8510.109984
# day 36: buy 1 unit at price 789.909973, total balance 7720.200011
# day 37: buy 1 unit at price 791.549988, total balance 6928.650023
# day 39: buy 1 unit at price 782.789978, total balance 6145.860045
# day 40: buy 1 unit at price 771.820007, total balance 5374.040038
# day 42, sell 1 unit at price 786.900024, investment -0.964052 %, total balance 6160.940062,
# day 43, sell 1 unit at price 794.020020, investment 0.348812 %, total balance 6954.960082,
# day 44, sell 1 unit at price 806.150024, investment 2.055937 %, total balance 7761.110106,
# day 45, sell 1 unit at price 806.650024, investment 1.907654 %, total balance 8567.760130,
# day 46, sell 1 unit at price 804.789978, investment 2.810460 %, total balance 9372.550108,
# day 47: buy 1 unit at price 807.909973, total balance 8564.640135
# day 48: buy 1 unit at price 806.359985, total balance 7758.280150
# day 50: buy 1 unit at price 804.609985, total balance 6953.670165
# day 51: buy 1 unit at price 806.070007, total balance 6147.600158
# day 52: buy 1 unit at price 802.174988, total balance 5345.425170
# day 53: buy 1 unit at price 805.020020, total balance 4540.405150
# day 54, sell 1 unit at price 819.309998, investment 6.152988 %, total balance 5359.715148,
# day 55: buy 1 unit at price 823.869995, total balance 4535.845153
# day 57: buy 1 unit at price 832.150024, total balance 3703.695129
# day 58: buy 1 unit at price 823.309998, total balance 2880.385131
# day 59: buy 1 unit at price 802.320007, total balance 2078.065124
# day 60, sell 1 unit at price 796.789978, investment -1.376390 %, total balance 2874.855102,
# day 61, sell 1 unit at price 795.695007, investment -1.322608 %, total balance 3670.550109,
# day 62: buy 1 unit at price 798.530029, total balance 2872.020080
# day 63: buy 1 unit at price 801.489990, total balance 2070.530090
# day 64: buy 1 unit at price 801.340027, total balance 1269.190063
# day 65: buy 1 unit at price 806.969971, total balance 462.220092
# day 66: buy 1 unit at price 808.380005, total balance -346.159913
# day 67: buy 1 unit at price 809.559998, total balance -1155.719911
# day 68: buy 1 unit at price 813.669983, total balance -1969.389894
# day 71, sell 1 unit at price 818.979980, investment 1.785958 %, total balance -1150.409914,
# day 72, sell 1 unit at price 824.159973, investment 2.244218 %, total balance -326.249941,
# day 73, sell 1 unit at price 828.070007, investment 3.228101 %, total balance 501.820066,
# day 74: buy 1 unit at price 831.659973, total balance -329.839907
# day 75: buy 1 unit at price 830.760010, total balance -1160.599917
# day 76: buy 1 unit at price 831.330017, total balance -1991.929934
# day 77: buy 1 unit at price 828.640015, total balance -2820.569949
# day 79, sell 1 unit at price 823.210022, investment 2.259571 %, total balance -1997.359927,
# day 82, sell 1 unit at price 829.080017, investment 0.632384 %, total balance -1168.279910,
# day 83: buy 1 unit at price 827.780029, total balance -1996.059939
# day 84, sell 1 unit at price 831.909973, investment -0.028847 %, total balance -1164.149966,
# day 85, sell 1 unit at price 835.369995, investment 1.464818 %, total balance -328.779971,
# day 86, sell 1 unit at price 838.679993, investment 4.531856 %, total balance 509.900022,
# day 87: buy 1 unit at price 843.250000, total balance -333.349978
# day 88, sell 1 unit at price 845.539978, investment 5.887061 %, total balance 512.190000,
# day 89: buy 1 unit at price 845.619995, total balance -333.429995
# day 90, sell 1 unit at price 847.200012, investment 5.703131 %, total balance 513.770017,
# day 91: buy 1 unit at price 848.780029, total balance -335.010012
# day 92, sell 1 unit at price 852.119995, investment 6.336882 %, total balance 517.109983,
# day 93: buy 1 unit at price 848.400024, total balance -331.290041
# day 94: buy 1 unit at price 830.460022, total balance -1161.750063
# day 95: buy 1 unit at price 829.590027, total balance -1991.340090
# day 96: buy 1 unit at price 817.580017, total balance -2808.920107
# day 97: buy 1 unit at price 814.429993, total balance -3623.350100
# day 98: buy 1 unit at price 819.510010, total balance -4442.860110
# day 99: buy 1 unit at price 820.919983, total balance -5263.780093
# day 101: buy 1 unit at price 831.500000, total balance -6095.280093
# day 102: buy 1 unit at price 829.559998, total balance -6924.840091
# day 103, sell 1 unit at price 838.549988, investment 3.913407 %, total balance -6086.290103,
# day 104: buy 1 unit at price 834.570007, total balance -6920.860110
# day 105, sell 1 unit at price 831.409973, investment 2.848904 %, total balance -6089.450137,
# day 106: buy 1 unit at price 827.880005, total balance -6917.330142
# day 107: buy 1 unit at price 824.669983, total balance -7742.000125
# day 108, sell 1 unit at price 824.729980, investment 1.873855 %, total balance -6917.270145,
# day 109: buy 1 unit at price 823.349976, total balance -7740.620121
# day 110: buy 1 unit at price 824.320007, total balance -8564.940128
# day 111: buy 1 unit at price 823.559998, total balance -9388.500126
# day 112: buy 1 unit at price 837.169983, total balance -10225.670109
# day 114: buy 1 unit at price 838.210022, total balance -11063.880131
# day 116: buy 1 unit at price 843.190002, total balance -11907.070133
# day 117, sell 1 unit at price 862.760010, investment 6.033162 %, total balance -11044.310123,
# day 118, sell 1 unit at price 872.299988, investment 4.886614 %, total balance -10172.010135,
# day 119: buy 1 unit at price 871.729980, total balance -11043.740115
# day 120, sell 1 unit at price 874.250000, investment 5.234964 %, total balance -10169.490115,
# day 121: buy 1 unit at price 905.960022, total balance -11075.450137
# day 122, sell 1 unit at price 912.570007, investment 9.772291 %, total balance -10162.880130,
# day 123, sell 1 unit at price 916.440002, investment 10.595673 %, total balance -9246.440128,
# day 124: buy 1 unit at price 927.039978, total balance -10173.480106
# day 129: buy 1 unit at price 928.780029, total balance -11102.260135
# day 130: buy 1 unit at price 930.599976, total balance -12032.860111
# day 131: buy 1 unit at price 932.219971, total balance -12965.080082
# day 132: buy 1 unit at price 937.080017, total balance -13902.160099
# day 133: buy 1 unit at price 943.000000, total balance -14845.160099
# day 134: buy 1 unit at price 919.619995, total balance -15764.780094
# day 135: buy 1 unit at price 930.239990, total balance -16695.020084
# day 136: buy 1 unit at price 934.010010, total balance -17629.030094
# day 137: buy 1 unit at price 941.859985, total balance -18570.890079
# day 138, sell 1 unit at price 948.820007, investment 14.622239 %, total balance -17622.070072,
# day 139: buy 1 unit at price 954.960022, total balance -18577.030094
# day 140, sell 1 unit at price 969.539978, investment 14.976576 %, total balance -17607.490116,
# day 141, sell 1 unit at price 971.469971, investment 14.882569 %, total balance -16636.020145,
# day 142: buy 1 unit at price 975.880005, total balance -17611.900150
# day 143: buy 1 unit at price 964.859985, total balance -18576.760135
# day 144: buy 1 unit at price 966.950012, total balance -19543.710147
# day 146: buy 1 unit at price 983.679993, total balance -20527.390140
# day 147, sell 1 unit at price 976.570007, investment 15.055724 %, total balance -19550.820133,
# day 148: buy 1 unit at price 980.940002, total balance -20531.760135
# day 150: buy 1 unit at price 949.830017, total balance -21481.590152
# day 151: buy 1 unit at price 942.900024, total balance -22424.490176
# day 152, sell 1 unit at price 953.400024, investment 12.376237 %, total balance -21471.090152,
# day 153: buy 1 unit at price 950.760010, total balance -22421.850162
# day 154, sell 1 unit at price 942.309998, investment 13.468436 %, total balance -21479.540164,
# day 155, sell 1 unit at price 939.780029, investment 13.282465 %, total balance -20539.760135,
# day 156, sell 1 unit at price 957.369995, investment 17.098018 %, total balance -19582.390140,
# day 157, sell 1 unit at price 950.630005, investment 16.723354 %, total balance -18631.760135,
# day 158, sell 1 unit at price 959.450012, investment 17.076058 %, total balance -17672.310123,
# day 159: buy 1 unit at price 957.090027, total balance -18629.400150
# day 160: buy 1 unit at price 965.590027, total balance -19594.990177
# day 162: buy 1 unit at price 927.330017, total balance -20522.320194
# day 163, sell 1 unit at price 940.489990, investment 14.565367 %, total balance -19581.830204,
# day 164: buy 1 unit at price 917.789978, total balance -20499.620182
# day 165: buy 1 unit at price 908.729980, total balance -21408.350162
# day 166: buy 1 unit at price 898.700012, total balance -22307.050174
# day 167: buy 1 unit at price 911.710022, total balance -23218.760196
# day 169: buy 1 unit at price 918.590027, total balance -24137.350223
# day 170, sell 1 unit at price 928.799988, investment 11.701742 %, total balance -23208.550235,
# day 171: buy 1 unit at price 930.090027, total balance -24138.640262
# day 172, sell 1 unit at price 943.830017, investment 13.774774 %, total balance -23194.810245,
# day 173, sell 1 unit at price 947.159973, investment 13.490775 %, total balance -22247.650272,
# day 174, sell 1 unit at price 955.989990, investment 15.474463 %, total balance -21291.660282,
# day 175, sell 1 unit at price 953.419983, investment 15.612306 %, total balance -20338.240299,
# day 176, sell 1 unit at price 965.400024, investment 17.252694 %, total balance -19372.840275,
# day 177, sell 1 unit at price 970.890015, investment 17.780717 %, total balance -18401.950260,
# day 178: buy 1 unit at price 968.150024, total balance -19370.100284
# day 179, sell 1 unit at price 972.919983, investment 18.135896 %, total balance -18397.180301,
# day 180, sell 1 unit at price 980.340027, investment 17.101670 %, total balance -17416.840274,
# day 181: buy 1 unit at price 950.700012, total balance -18367.540286
# day 182: buy 1 unit at price 947.799988, total balance -19315.340274
# day 183: buy 1 unit at price 934.090027, total balance -20249.430301
# day 185: buy 1 unit at price 930.500000, total balance -21179.930301
# day 186, sell 1 unit at price 930.830017, investment 11.049736 %, total balance -20249.100284,
# day 187, sell 1 unit at price 930.390015, investment 10.341680 %, total balance -19318.710269,
# day 188, sell 1 unit at price 923.650024, investment 5.955978 %, total balance -18395.060245,
# day 189: buy 1 unit at price 927.960022, total balance -19323.020267
# day 190: buy 1 unit at price 929.359985, total balance -20252.380252
# day 191, sell 1 unit at price 926.789978, investment 2.299214 %, total balance -19325.590274,
# day 192: buy 1 unit at price 922.900024, total balance -20248.490298
# day 193: buy 1 unit at price 907.239990, total balance -21155.730288
# day 194, sell 1 unit at price 914.390015, investment -1.364554 %, total balance -20241.340273,
# day 195, sell 1 unit at price 922.669983, investment -0.657857 %, total balance -19318.670290,
# day 196: buy 1 unit at price 922.219971, total balance -20240.890261
# day 197, sell 1 unit at price 926.960022, investment -0.391141 %, total balance -19313.930239,
# day 198: buy 1 unit at price 910.979980, total balance -20224.910219
# day 199, sell 1 unit at price 910.669983, investment -2.311685 %, total balance -19314.240236,
# day 200: buy 1 unit at price 906.659973, total balance -20220.900209
# day 201, sell 1 unit at price 924.690002, investment -1.322194 %, total balance -19296.210207,
# day 202, sell 1 unit at price 927.000000, investment -1.696713 %, total balance -18369.210207,
# day 203: buy 1 unit at price 921.280029, total balance -19290.490236
# day 204, sell 1 unit at price 915.890015, investment -0.405600 %, total balance -18374.600221,
# day 205: buy 1 unit at price 913.809998, total balance -19288.410219
# day 206, sell 1 unit at price 921.289978, investment -0.962119 %, total balance -18367.120241,
# day 207, sell 1 unit at price 929.570007, investment -0.475370 %, total balance -17437.550234,
# day 208, sell 1 unit at price 939.330017, investment -0.268614 %, total balance -16498.220217,
# day 209: buy 1 unit at price 937.340027, total balance -17435.560244
# day 210: buy 1 unit at price 928.450012, total balance -18364.010256
# day 211, sell 1 unit at price 927.809998, investment -2.843053 %, total balance -17436.200258,
# day 212, sell 1 unit at price 935.950012, investment -4.091691 %, total balance -16500.250246,
# day 213: buy 1 unit at price 926.500000, total balance -17426.750246
# day 214, sell 1 unit at price 929.080017, investment -3.708307 %, total balance -16497.670229,
# day 215: buy 1 unit at price 932.070007, total balance -17429.740236
# day 216: buy 1 unit at price 935.090027, total balance -18364.830263
# day 217, sell 1 unit at price 925.109985, investment -4.327010 %, total balance -17439.720278,
# day 218, sell 1 unit at price 920.289978, investment -6.444170 %, total balance -16519.430300,
# day 219, sell 1 unit at price 915.000000, investment -6.722124 %, total balance -15604.430300,
# day 220, sell 1 unit at price 921.809998, investment -2.950004 %, total balance -14682.620302,
# day 221: buy 1 unit at price 931.580017, total balance -15614.200319
# day 222: buy 1 unit at price 932.450012, total balance -16546.650331
# day 223, sell 1 unit at price 928.530029, investment -1.524021 %, total balance -15618.120302,
# day 224, sell 1 unit at price 920.969971, investment -3.133287 %, total balance -14697.150331,
# day 225, sell 1 unit at price 924.859985, investment -3.367504 %, total balance -13772.290346,
# day 226, sell 1 unit at price 944.489990, investment -2.185196 %, total balance -12827.800356,
# day 227, sell 1 unit at price 949.500000, investment 2.390733 %, total balance -11878.300356,
# day 228: buy 1 unit at price 959.109985, total balance -12837.410341
# day 229, sell 1 unit at price 953.270020, investment 3.865813 %, total balance -11884.140321,
# day 230, sell 1 unit at price 957.789978, investment 5.398743 %, total balance -10926.350343,
# day 231: buy 1 unit at price 951.679993, total balance -11878.030336
# day 232, sell 1 unit at price 969.960022, investment 7.929232 %, total balance -10908.070314,
# day 234: buy 1 unit at price 977.000000, total balance -11885.070314
# day 235: buy 1 unit at price 972.599976, total balance -12857.670290
# day 236, sell 1 unit at price 989.250000, investment 8.504895 %, total balance -11868.420290,
# day 237, sell 1 unit at price 987.830017, investment 7.537638 %, total balance -10880.590273,
# day 238, sell 1 unit at price 989.679993, investment 6.406903 %, total balance -9890.910280,
# day 239: buy 1 unit at price 992.000000, total balance -10882.910280
# day 240, sell 1 unit at price 992.179993, investment 2.482050 %, total balance -9890.730287,
# day 241: buy 1 unit at price 992.809998, total balance -10883.540285
# day 242: buy 1 unit at price 984.450012, total balance -11867.990297
# day 243, sell 1 unit at price 988.200012, investment 3.944462 %, total balance -10879.790285,
# day 244, sell 1 unit at price 968.450012, investment 2.178732 %, total balance -9911.340273,
# day 246: buy 1 unit at price 973.330017, total balance -10884.670290
# day 247: buy 1 unit at price 972.559998, total balance -11857.230288
# day 248, sell 1 unit at price 1019.270020, investment 9.119035 %, total balance -10837.960268,
# day 249, sell 1 unit at price 1017.109985, investment 9.307897 %, total balance -9820.850283,
# day 250, sell 1 unit at price 1016.640015, investment 9.556445 %, total balance -8804.210268,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
