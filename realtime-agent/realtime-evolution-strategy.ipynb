# %%
from sklearn.preprocessing import MinMaxScaler
import os
import numpy as np
import pandas as pd
import time
import random

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def softmax(z):
    assert len(z.shape) == 2
    s = np.max(z, axis=1)
    s = s[:, np.newaxis]
    e_x = np.exp(z - s)
    div = np.sum(e_x, axis=1)
    div = div[:, np.newaxis]
    return e_x / div

# %%
df = pd.read_csv('FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-23  182.500000  186.910004  182.179993  186.899994  186.899994
# 1  2018-05-24  185.880005  186.800003  185.029999  185.929993  185.929993
# 2  2018-05-25  186.020004  186.330002  184.449997  184.919998  184.919998
# 3  2018-05-29  184.339996  186.809998  183.710007  185.740005  185.740005
# 4  2018-05-30  186.539993  188.000000  185.250000  187.669998  187.669998
#
#      Volume
# 0  16628100
# 1  12354700
# 2  10965100
# 3  16398900
# 4  13736900

# %%
parameters = [df['Close'].tolist(), df['Volume'].tolist()]

# %%
def get_state(parameters, t, window_size = 20):
    outside = []
    d = t - window_size + 1
    for parameter in parameters:
        block = (
            parameter[d : t + 1]
            if d >= 0
            else -d * [parameter[0]] + parameter[0 : t + 1]
        )
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        for i in range(1, window_size, 1):
            res.append(block[i] - block[0])
        outside.append(res)
    return np.array(outside).reshape((1, -1))

# %% [markdown]
# Our output size from `get_state` is 38. In this notebook, I only use `Close` and `Volume` parameters, you can choose any parameters you want from your DataFrame.
#
# After that, I want to add another parameters, my `inventory` size, mean of `inventory` and `capital`.
#
# Let say for an example,
# ```
# inventory_size = 1
# mean_inventory = 0.5
# capital = 2
# last_state = 0
# ```
#
# We have 3 actions,
#
# 1. `0` for do nothing.
# 2. `1` for buy.
# 3. `2` for sell.

# %%
inventory_size = 1
mean_inventory = 0.5
capital = 2
concat_parameters = np.concatenate([get_state(parameters, 20), [[inventory_size, 
                                                                mean_inventory,
                                                                capital]]], axis = 1)

# %%
input_size = concat_parameters.shape[1]
input_size
# Out:
# 79

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights
    
    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')
        
class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.rand(input_size, layer_size)
            * np.sqrt(1 / (input_size + layer_size)),
            np.random.rand(layer_size, output_size)
            * np.sqrt(1 / (layer_size + output_size)),
            np.zeros((1, layer_size)),
            np.zeros((1, output_size)),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-2]
        decision = np.dot(feed, self.weights[1]) + self.weights[-1]
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, timeseries, skip, initial_money, real_trend, minmax):
        self.model = model
        self.timeseries = timeseries
        self.skip = skip
        self.real_trend = real_trend
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )
        self.minmax = minmax
        self._initiate()

    def _initiate(self):
        # i assume first index is the close value
        self.trend = self.timeseries[0]
        self._mean = np.mean(self.trend)
        self._std = np.std(self.trend)
        self._inventory = []
        self._capital = self.initial_money
        self._queue = []
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]

    def reset_capital(self, capital):
        if capital:
            self._capital = capital
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]
        self._queue = []
        self._inventory = []

    def trade(self, data):
        """
        you need to make sure the data is [close, volume]
        """
        scaled_data = self.minmax.transform([data])[0]
        real_close = data[0]
        close = scaled_data[0]
        if len(self._queue) >= window_size:
            self._queue.pop(0)
        self._queue.append(scaled_data)
        if len(self._queue) < window_size:
            return {
                'status': 'data not enough to trade',
                'action': 'fail',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        state = self.get_state(
            window_size - 1,
            self._inventory,
            self._scaled_capital,
            timeseries = np.array(self._queue).T.tolist(),
        )
        action, prob = self.act_softmax(state)
        print(prob)
        if action == 1 and self._scaled_capital >= close:
            self._inventory.append(close)
            self._scaled_capital -= close
            self._capital -= real_close
            return {
                'status': 'buy 1 unit, cost %f' % (real_close),
                'action': 'buy',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        elif action == 2 and len(self._inventory):
            bought_price = self._inventory.pop(0)
            self._scaled_capital += close
            self._capital += real_close
            scaled_bought_price = self.minmax.inverse_transform(
                [[bought_price, 2]]
            )[0, 0]
            try:
                invest = (
                    (real_close - scaled_bought_price) / scaled_bought_price
                ) * 100
            except:
                invest = 0
            return {
                'status': 'sell 1 unit, price %f' % (real_close),
                'investment': invest,
                'gain': real_close - scaled_bought_price,
                'balance': self._capital,
                'action': 'sell',
                'timestamp': str(datetime.now()),
            }
        else:
            return {
                'status': 'do nothing',
                'action': 'nothing',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }

    def change_data(self, timeseries, skip, initial_money, real_trend, minmax):
        self.timeseries = timeseries
        self.skip = skip
        self.initial_money = initial_money
        self.real_trend = real_trend
        self.minmax = minmax
        self._initiate()

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0])

    def act_softmax(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0]), softmax(decision)[0]

    def get_state(self, t, inventory, capital, timeseries):
        state = get_state(timeseries, t)
        len_inventory = len(inventory)
        if len_inventory:
            mean_inventory = np.mean(inventory)
        else:
            mean_inventory = 0
        z_inventory = (mean_inventory - self._mean) / self._std
        z_capital = (capital - self._mean) / self._std
        concat_parameters = np.concatenate(
            [state, [[len_inventory, z_inventory, z_capital]]], axis = 1
        )
        return concat_parameters

    def get_reward(self, weights):
        initial_money = self._scaled_capital
        starting_money = initial_money
        invests = []
        self.model.weights = weights
        inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)

        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= self.trend[t]

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]
                invest = ((self.trend[t] - bought_price) / bought_price) * 100
                invests.append(invest)

            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )
        invests = np.mean(invests)
        if np.isnan(invests):
            invests = 0
        score = (starting_money - initial_money) / initial_money * 100
        return invests * 0.7 + score * 0.3

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self._scaled_capital
        starting_money = initial_money

        real_initial_money = self.initial_money
        real_starting_money = self.initial_money
        inventory = []
        real_inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)
        states_sell = []
        states_buy = []

        for t in range(0, len(self.trend) - 1, self.skip):
            action, prob = self.act_softmax(state)
            print(t, prob)

            if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - 1 - window_size):
                inventory.append(self.trend[t])
                real_inventory.append(self.real_trend[t])
                real_starting_money -= self.real_trend[t]
                starting_money -= self.trend[t]
                states_buy.append(t)
                print(
                    'day %d: buy 1 unit at price %f, total balance %f'
                    % (t, self.real_trend[t], real_starting_money)
                )

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                real_bought_price = real_inventory.pop(0)
                starting_money += self.trend[t]
                real_starting_money += self.real_trend[t]
                states_sell.append(t)
                try:
                    invest = (
                        (self.real_trend[t] - real_bought_price)
                        / real_bought_price
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.real_trend[t], invest, real_starting_money)
                )
            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )

        invest = (
            (real_starting_money - real_initial_money) / real_initial_money
        ) * 100
        total_gains = real_starting_money - real_initial_money
        return states_buy, states_sell, total_gains, invest

# %%
stocks = [i for i in os.listdir(os.getcwd()) if '.csv' in i and not 'TWTR' in i]
stocks
# Out:
# ['AMD.csv',
#  'CPRT.csv',
#  'FB.csv',
#  'FSV.csv',
#  'GOOG.csv',
#  'GWR.csv',
#  'LB.csv',
#  'LYFT.csv',
#  'MTDR.csv',
#  'SINA.csv',
#  'TSLA.csv']

# %% [markdown]
# I want to train on all stocks I downloaded except for Twitter. I want to use Twitter for testing.

# %%
skip = 1
layer_size = 500
output_size = 3
window_size = 20

# %%
model = Model(input_size = input_size, layer_size = layer_size, output_size = output_size)
agent = None

for no, stock in enumerate(stocks):
    print('training stock %s'%(stock))
    df = pd.read_csv(stock)
    real_trend = df['Close'].tolist()
    parameters = [df['Close'].tolist(), df['Volume'].tolist()]
    minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
    scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
    initial_money = np.max(parameters[0]) * 2
    
    if no == 0:
        agent = Agent(model = model,
                      timeseries = scaled_parameters,
                      skip = skip,
                      initial_money = initial_money,
                      real_trend = real_trend,
                      minmax = minmax)
    else:
        agent.change_data(timeseries = scaled_parameters,
                          skip = skip,
                          initial_money = initial_money,
                          real_trend = real_trend,
                          minmax = minmax)
    
    agent.fit(iterations = 100, checkpoint = 10)
    print()
# Out:
# training stock AMD.csv
# iter 10. reward: 25.535647
# iter 20. reward: 35.717604
# iter 30. reward: 41.981386
# iter 40. reward: 41.502908
# iter 50. reward: 42.372546
# iter 60. reward: 43.097087
# iter 70. reward: 47.407295
# iter 80. reward: 45.272029
# iter 90. reward: 47.809585
# iter 100. reward: 48.174366
# time taken to train: 45.93911051750183 seconds
#
# training stock CPRT.csv
# iter 10. reward: -10.710981
# iter 20. reward: -8.165902
# iter 30. reward: -6.367104
# iter 40. reward: -4.006842
# iter 50. reward: -7.989651
# iter 60. reward: -7.757883
# iter 70. reward: -10.824944
# iter 80. reward: -3.581459
# iter 90. reward: -4.418014
# iter 100. reward: -4.591668
# time taken to train: 44.23793029785156 seconds
#
# training stock FB.csv
# iter 10. reward: -6.848069
# iter 20. reward: -6.850581
# iter 30. reward: -6.783747
# iter 40. reward: -6.494892
# iter 50. reward: -6.841161
# iter 60. reward: -6.842162
# iter 70. reward: -6.188132
# iter 80. reward: 5.348416
# iter 90. reward: 5.363901
# iter 100. reward: 5.548333
# time taken to train: 42.67542743682861 seconds
#
# training stock FSV.csv
# iter 10. reward: 28.149080
# iter 20. reward: 30.334506
# iter 30. reward: 33.143604
# iter 40. reward: 33.143604
# iter 50. reward: 33.679526
# iter 60. reward: 34.224516
# iter 70. reward: 35.879126
# iter 80. reward: 36.021337
# iter 90. reward: 36.210541
# iter 100. reward: 36.210541
# time taken to train: 42.3166663646698 seconds
#
# training stock GOOG.csv
# iter 10. reward: 0.964130
# iter 20. reward: 3.855093
# iter 30. reward: 9.056833
# iter 40. reward: 17.157515
# iter 50. reward: 24.987842
# iter 60. reward: 24.987842
# iter 70. reward: 26.382090
# iter 80. reward: 27.948371
# iter 90. reward: 27.487507
# iter 100. reward: 28.607992
# time taken to train: 41.397642850875854 seconds
#
# training stock GWR.csv
# iter 10. reward: 20.272007
# iter 20. reward: 29.530608
# iter 30. reward: 35.573198
# iter 40. reward: 35.573198
# iter 50. reward: 36.944737
# iter 60. reward: 36.944737
# iter 70. reward: 37.549800
# iter 80. reward: 37.549800
# iter 90. reward: 36.911811
# iter 100. reward: 37.019485
# time taken to train: 42.58565926551819 seconds
#
# training stock LB.csv
# iter 10. reward: -2.691531
# iter 20. reward: 0.360251
# iter 30. reward: 5.793559
# iter 40. reward: 6.871433
# iter 50. reward: 10.030939
# iter 60. reward: 10.183078
# iter 70. reward: 11.324531
# iter 80. reward: 11.644259
# iter 90. reward: 11.305283
# iter 100. reward: 12.302313
# time taken to train: 41.11907625198364 seconds
#
# training stock LYFT.csv
# c:\Users\joshu\miniconda3\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\joshu\miniconda3\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# iter 10. reward: 0.000000
# iter 20. reward: 0.000000
# iter 30. reward: 0.000000
# iter 40. reward: 0.000000
# iter 50. reward: 0.000000
# iter 60. reward: 0.000000
# iter 70. reward: 0.000000
# iter 80. reward: 0.000000
# iter 90. reward: 0.000000
# iter 100. reward: 0.000000
# time taken to train: 8.042256593704224 seconds
#
# training stock MTDR.csv
# iter 10. reward: -4.526896
# iter 20. reward: -0.902948
# iter 30. reward: -2.938320
# iter 40. reward: -1.286750
# iter 50. reward: -3.087736
# iter 60. reward: -0.416304
# iter 70. reward: -0.286518
# iter 80. reward: 1.922727
# iter 90. reward: 2.851901
# iter 100. reward: 1.897267
# time taken to train: 40.7800133228302 seconds
#
# training stock SINA.csv
# iter 10. reward: -4.377241
# iter 20. reward: -3.846587
# iter 30. reward: -1.821420
# iter 40. reward: -1.575266
# iter 50. reward: -0.646143
# iter 60. reward: -0.071051
# iter 70. reward: 1.732815
# iter 80. reward: 1.929084
# iter 90. reward: 1.996748
# iter 100. reward: 4.205812
# time taken to train: 41.33114528656006 seconds
#
# training stock TSLA.csv
# iter 10. reward: -4.880448
# iter 20. reward: -3.196536
# iter 30. reward: 0.394395
# iter 40. reward: 1.025021
# iter 50. reward: 1.322604
# iter 60. reward: 1.381769
# iter 70. reward: 1.250786
# iter 80. reward: 1.375527
# iter 90. reward: 1.197353
# iter 100. reward: 4.437962
# time taken to train: 41.727813959121704 seconds

# %% [markdown]
# ### If you saw the whole training session on certain stocks are negatives (like FB), means that, that stock markets are losing very bad

# %%
df = pd.read_csv('../dataset/GOOG.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

    
agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [0. 0. 1.]
# 1 [1. 0. 0.]
# 2 [0. 0. 1.]
# 3 [1.00000000e+00 0.00000000e+00 3.13839038e-67]
# 4 [0. 0. 1.]
# 5 [1. 0. 0.]
# 6 [1. 0. 0.]
# 7 [0. 0. 1.]
# 8 [0. 0. 1.]
# 9 [0. 1. 0.]
# 10 [1. 0. 0.]
# 11 [0. 0. 1.]
# 12 [0. 1. 0.]
# 13 [0. 1. 0.]
# 14 [0. 1. 0.]
# 15 [0. 0. 1.]
# 16 [0. 1. 0.]
# 17 [1. 0. 0.]
# 18 [1. 0. 0.]
# 19 [0. 0. 1.]
# 20 [0. 1. 0.]
# 21 [1. 0. 0.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('GOOG total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
df = pd.read_csv('TWTR.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [0. 0. 1.]
# 1 [0. 0. 1.]
# 2 [0. 0. 1.]
# 3 [0. 0. 1.]
# 4 [0. 0. 1.]
# 5 [0. 0. 1.]
# 6 [0. 0. 1.]
# 7 [0. 0. 1.]
# 8 [0. 0. 1.]
# 9 [0. 0. 1.]
# 10 [0. 1. 0.]
# day 10: buy 1 unit at price 39.700001, total balance 53.819995
# 11 [0. 1. 0.]
# day 11: buy 1 unit at price 41.209999, total balance 12.609996
# 12 [1. 0. 0.]
# 13 [0. 1. 0.]
# 14 [0. 1. 0.]
# 15 [0. 1. 0.]
# 16 [0. 1. 0.]
# 17 [0. 1. 0.]
# 18 [0. 1. 0.]
# 19 [1. 0. 0.]
# 20 [0. 0. 1.]
# day 20, sell 1 unit at price 45.240002, investment 13.954662 %, total balance 57.849998,
# 21 [0. 0. 1.]
# day 21, sell 1 unit at price 45.880001, investment 11.332206 %, total balance 103.729999,
# 22 [1. 0. 0.]
# 23 [1. 0. 0.]
# 24 [0. 0. 1.]
# 25 [0. 0. 1.]
# 26 [1. 0. 0.]
# 27 [1. 0. 0.]
# 28 [1. 0. 0.]
# 29 [1. 0. 0.]
# 30 [1. 0. 0.]
# 31 [0. 0. 1.]
# 32 [0. 1. 0.]
# day 32: buy 1 unit at price 43.750000, total balance 59.979999
# 33 [1. 0. 0.]
# 34 [1. 0. 0.]
# 35 [0.00000000e+000 1.00000000e+000 2.97918204e-260]
# day 35: buy 1 unit at price 44.490002, total balance 15.489997
# 36 [0. 1. 0.]
# 37 [0. 0. 1.]
# day 37, sell 1 unit at price 44.709999, investment 2.194283 %, total balance 60.199996,
# 38 [0. 1. 0.]
# day 38: buy 1 unit at price 43.340000, total balance 16.859996
# 39 [1. 0. 0.]
# 40 [0. 1. 0.]
# 41 [1. 0. 0.]
# 42 [0. 0. 1.]
# day 42, sell 1 unit at price 42.169998, investment -5.214664 %, total balance 59.029994,
# 43 [0. 0. 1.]
# day 43, sell 1 unit at price 44.220001, investment 2.030459 %, total balance 103.249995,
# 44 [1. 0. 0.]
# 45 [0. 0. 1.]
# 46 [0. 1. 0.]
# day 46: buy 1 unit at price 31.379999, total balance 71.869996
# 47 [0. 0. 1.]
# day 47, sell 1 unit at price 31.870001, investment 1.561511 %, total balance 103.739997,
# 48 [1. 0. 0.]
# 49 [0. 1. 0.]
# day 49: buy 1 unit at price 32.820000, total balance 70.919997
# 50 [0. 0. 1.]
# day 50, sell 1 unit at price 31.959999, investment -2.620356 %, total balance 102.879996,
# 51 [0. 0. 1.]
# 52 [0. 1. 0.]
# day 52: buy 1 unit at price 32.669998, total balance 70.209998
# 53 [0. 0. 1.]
# day 53, sell 1 unit at price 31.840000, investment -2.540551 %, total balance 102.049998,
# 54 [0. 0. 1.]
# 55 [1. 0. 0.]
# 56 [0. 0. 1.]
# 57 [0. 0. 1.]
# 58 [0. 0. 1.]
# 59 [0. 0. 1.]
# 60 [0. 0. 1.]
# 61 [0. 0. 1.]
# 62 [1. 0. 0.]
# 63 [0. 1. 0.]
# day 63: buy 1 unit at price 33.810001, total balance 68.239997
# 64 [0. 1. 0.]
# day 64: buy 1 unit at price 33.880001, total balance 34.359996
# 65 [0. 1. 0.]
# day 65: buy 1 unit at price 34.279999, total balance 0.079997
# 66 [1. 0. 0.]
# 67 [1. 0. 0.]
# 68 [0. 1. 0.]
# 69 [0. 1. 0.]
# 70 [1. 0. 0.]
# 71 [0. 1. 0.]
# 72 [0. 0. 1.]
# day 72, sell 1 unit at price 32.730000, investment -3.194324 %, total balance 32.809997,
# 73 [0. 1. 0.]
# day 73: buy 1 unit at price 30.809999, total balance 1.999998
# 74 [0. 1. 0.]
# 75 [2.68546167e-220 1.00000000e+000 0.00000000e+000]
# 76 [1. 0. 0.]
# 77 [1. 0. 0.]
# 78 [0. 0. 1.]
# day 78, sell 1 unit at price 30.389999, investment -10.301068 %, total balance 32.389997,
# 79 [0. 0. 1.]
# day 79, sell 1 unit at price 30.120001, investment -12.135350 %, total balance 62.509998,
# 80 [1. 0. 0.]
# 81 [1. 0. 0.]
# 82 [0. 0. 1.]
# day 82, sell 1 unit at price 29.520000, investment -4.186949 %, total balance 92.029998,
# 83 [0. 0. 1.]
# 84 [0. 0. 1.]
# 85 [0. 0. 1.]
# 86 [0. 0. 1.]
# 87 [0. 0. 1.]
# 88 [0. 0. 1.]
# 89 [0. 0. 1.]
# 90 [0. 0. 1.]
# 91 [0. 1. 0.]
# day 91: buy 1 unit at price 28.190001, total balance 63.839997
# 92 [1. 0. 0.]
# 93 [0.00000000e+000 1.00000000e+000 4.10103554e-162]
# day 93: buy 1 unit at price 28.230000, total balance 35.609997
# 94 [1. 0. 0.]
# 95 [0. 1. 0.]
# day 95: buy 1 unit at price 28.450001, total balance 7.159996
# 96 [0. 0. 1.]
# day 96, sell 1 unit at price 29.270000, investment 3.831142 %, total balance 36.429996,
# 97 [1. 0. 0.]
# 98 [0. 1. 0.]
# day 98: buy 1 unit at price 27.000000, total balance 9.429996
# 99 [0. 1. 0.]
# 100 [0. 0. 1.]
# day 100, sell 1 unit at price 28.610001, investment 1.346089 %, total balance 38.039997,
# 101 [1. 0. 0.]
# 102 [1.00000000e+000 8.64610118e-201 0.00000000e+000]
# 103 [0. 0. 1.]
# day 103, sell 1 unit at price 29.290001, investment 2.952548 %, total balance 67.329998,
# 104 [0. 0. 1.]
# day 104, sell 1 unit at price 28.830000, investment 6.777778 %, total balance 96.159998,
# 105 [0. 1. 0.]
# day 105: buy 1 unit at price 29.180000, total balance 66.979998
# 106 [1. 0. 0.]
# 107 [1. 0. 0.]
# 108 [0. 0. 1.]
# day 108, sell 1 unit at price 31.799999, investment 8.978749 %, total balance 98.779997,
# 109 [0. 0. 1.]
# 110 [3.97918361e-261 1.00000000e+000 0.00000000e+000]
# day 110: buy 1 unit at price 32.389999, total balance 66.389998
# 111 [1. 0. 0.]
# 112 [0. 1. 0.]
# day 112: buy 1 unit at price 34.750000, total balance 31.639998
# 113 [0. 1. 0.]
# day 113: buy 1 unit at price 34.619999, total balance -2.980001
# 114 [0. 1. 0.]
# 115 [0. 1. 0.]
# 116 [0. 1. 0.]
# 117 [0. 1. 0.]
# 118 [1. 0. 0.]
# 119 [1. 0. 0.]
# 120 [0. 0. 1.]
# day 120, sell 1 unit at price 32.009998, investment -1.173205 %, total balance 29.029997,
# 121 [0. 1. 0.]
# day 121: buy 1 unit at price 32.490002, total balance -3.460005
# 122 [1. 0. 0.]
# 123 [1. 0. 0.]
# 124 [0. 0. 1.]
# day 124, sell 1 unit at price 33.669998, investment -3.107919 %, total balance 30.209993,
# 125 [1. 0. 0.]
# 126 [1. 0. 0.]
# 127 [1.00000000e+00 5.54704089e-69 0.00000000e+00]
# 128 [1. 0. 0.]
# 129 [1. 0. 0.]
# 130 [1. 0. 0.]
# 131 [1. 0. 0.]
# 132 [0. 0. 1.]
# day 132, sell 1 unit at price 31.299999, investment -9.589833 %, total balance 61.509992,
# 133 [0. 1. 0.]
# day 133: buy 1 unit at price 31.450001, total balance 30.059991
# 134 [0. 1. 0.]
# day 134: buy 1 unit at price 33.660000, total balance -3.600009
# 135 [1.24494561e-171 0.00000000e+000 1.00000000e+000]
# day 135, sell 1 unit at price 32.560001, investment 0.215448 %, total balance 28.959992,
# 136 [0. 1. 0.]
# day 136: buy 1 unit at price 32.959999, total balance -4.000007
# 137 [0. 0. 1.]
# day 137, sell 1 unit at price 32.830002, investment 4.387920 %, total balance 28.829995,
# 138 [0. 0. 1.]
# day 138, sell 1 unit at price 33.430000, investment -0.683304 %, total balance 62.259995,
# 139 [0. 1. 0.]
# day 139: buy 1 unit at price 34.450001, total balance 27.809994
# 140 [0. 1. 0.]
# day 140: buy 1 unit at price 36.250000, total balance -8.440006
# 141 [0. 1. 0.]
# 142 [0. 1. 0.]
# 143 [1. 0. 0.]
# 144 [0. 1. 0.]
# 145 [0. 0. 1.]
# day 145, sell 1 unit at price 32.930000, investment -0.091016 %, total balance 24.489994,
# 146 [0. 0. 1.]
# day 146, sell 1 unit at price 29.290001, investment -14.978229 %, total balance 53.779995,
# 147 [0. 1. 0.]
# day 147: buy 1 unit at price 27.309999, total balance 26.469996
# 148 [0. 0. 1.]
# day 148, sell 1 unit at price 26.450001, investment -27.034480 %, total balance 52.919997,
# 149 [1. 0. 0.]
# 150 [1. 0. 0.]
# 151 [9.84931559e-128 0.00000000e+000 1.00000000e+000]
# day 151, sell 1 unit at price 28.430000, investment 4.101066 %, total balance 81.349997,
# 152 [0. 0. 1.]
# 153 [0. 0. 1.]
# 154 [1. 0. 0.]
# 155 [0. 0. 1.]
# 156 [0. 0. 1.]
# 157 [0. 0. 1.]
# 158 [0. 0. 1.]
# 159 [0. 0. 1.]
# 160 [0. 0. 1.]
# 161 [0. 1. 0.]
# day 161: buy 1 unit at price 32.369999, total balance 48.979998
# 162 [0. 1. 0.]
# day 162: buy 1 unit at price 33.020000, total balance 15.959998
# 163 [1. 0. 0.]
# 164 [0. 1. 0.]
# 165 [0. 1. 0.]
# 166 [0. 1. 0.]
# 167 [3.46344107e-257 1.00000000e+000 0.00000000e+000]
# 168 [0. 1. 0.]
# 169 [1. 0. 0.]
# 170 [1. 0. 0.]
# 171 [1.00000000e+00 0.00000000e+00 2.26570918e-18]
# 172 [1. 0. 0.]
# 173 [0. 0. 1.]
# day 173, sell 1 unit at price 33.560001, investment 3.676250 %, total balance 49.519999,
# 174 [0. 0. 1.]
# day 174, sell 1 unit at price 33.189999, investment 0.514836 %, total balance 82.709998,
# 175 [0.00000000e+000 1.02066542e-298 1.00000000e+000]
# 176 [1. 0. 0.]
# 177 [0. 0. 1.]
# 178 [0. 0. 1.]
# 179 [0. 1. 0.]
# day 179: buy 1 unit at price 30.010000, total balance 52.699998
# 180 [3.05761919e-218 1.00000000e+000 0.00000000e+000]
# day 180: buy 1 unit at price 30.230000, total balance 22.469998
# 181 [0. 0. 1.]
# day 181, sell 1 unit at price 30.389999, investment 1.266241 %, total balance 52.859997,
# 182 [0. 0. 1.]
# day 182, sell 1 unit at price 31.120001, investment 2.944099 %, total balance 83.979998,
# 183 [1. 0. 0.]
# 184 [0. 0. 1.]
# 185 [0. 1. 0.]
# day 185: buy 1 unit at price 31.650000, total balance 52.329998
# 186 [0. 0. 1.]
# day 186, sell 1 unit at price 31.370001, investment -0.884673 %, total balance 83.699999,
# 187 [1. 0. 0.]
# 188 [1. 0. 0.]
# 189 [0. 0. 1.]
# 190 [0. 0. 1.]
# 191 [1. 0. 0.]
# 192 [0. 0. 1.]
# 193 [0. 0. 1.]
# 194 [0. 0. 1.]
# 195 [1. 0. 0.]
# 196 [1.00000000e+00 3.08657994e-34 0.00000000e+00]
# 197 [0. 1. 0.]
# day 197: buy 1 unit at price 30.120001, total balance 53.579998
# 198 [0. 1. 0.]
# day 198: buy 1 unit at price 30.040001, total balance 23.539997
# 199 [1. 0. 0.]
# 200 [8.98650875e-161 0.00000000e+000 1.00000000e+000]
# day 200, sell 1 unit at price 31.160000, investment 3.452852 %, total balance 54.699997,
# 201 [1. 0. 0.]
# 202 [1. 0. 0.]
# 203 [0. 0. 1.]
# day 203, sell 1 unit at price 31.219999, investment 3.928089 %, total balance 85.919996,
# 204 [0. 0. 1.]
# 205 [0. 0. 1.]
# 206 [0. 0. 1.]
# 207 [0. 0. 1.]
# 208 [1. 0. 0.]
# 209 [0. 1. 0.]
# day 209: buy 1 unit at price 32.590000, total balance 53.329996
# 210 [0. 1. 0.]
# day 210: buy 1 unit at price 33.060001, total balance 20.269995
# 211 [0. 0. 1.]
# day 211, sell 1 unit at price 32.279999, investment -0.951215 %, total balance 52.549994,
# 212 [0. 1. 0.]
# day 212: buy 1 unit at price 32.869999, total balance 19.679995
# 213 [0. 1. 0.]
# 214 [1. 0. 0.]
# 215 [0. 1. 0.]
# 216 [1. 0. 0.]
# 217 [0. 1. 0.]
# 218 [0. 1. 0.]
# 219 [1. 0. 0.]
# 220 [1. 0. 0.]
# 221 [0. 1. 0.]
# 222 [1. 0. 0.]
# 223 [4.49637678e-194 1.00000000e+000 0.00000000e+000]
# 224 [0. 0. 1.]
# day 224, sell 1 unit at price 34.709999, investment 4.990919 %, total balance 54.389994,
# 225 [0. 1. 0.]
# day 225: buy 1 unit at price 34.459999, total balance 19.929995
# 226 [1. 0. 0.]
# 227 [0. 1. 0.]
# 228 [0. 0. 1.]
# day 228, sell 1 unit at price 34.389999, investment 4.624278 %, total balance 54.319994,
# 229 [0. 0. 1.]
# day 229, sell 1 unit at price 39.770000, investment 15.409173 %, total balance 94.089994,
# 230 [0. 1. 0.]
# day 230: buy 1 unit at price 39.290001, total balance 54.799993
# 231 [1. 0. 0.]
# 232 [1. 0. 0.]
# 233 [0.00000000e+000 1.47912085e-159 1.00000000e+000]
# day 233, sell 1 unit at price 39.779999, investment 1.247132 %, total balance 94.579992,
# 234 [0. 0. 1.]
# 235 [0. 1. 0.]
# 236 [0. 1. 0.]
# 237 [0. 0. 1.]
# 238 [0. 1. 0.]
# 239 [1. 0. 0.]
# 240 [1. 0. 0.]
# 241 [0. 0. 1.]
# 242 [1. 0. 0.]
# 243 [1. 0. 0.]
# 244 [1. 0. 0.]
# 245 [0. 0. 1.]
# 246 [0. 0. 1.]
# 247 [1. 0. 0.]
# 248 [1. 0. 0.]
# 249 [0. 0. 1.]
# 250 [0. 0. 1.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('TWTR total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
from datetime import datetime

volume = df['Volume'].tolist()

for i in range(100):
    print(agent.trade([real_trend[i], volume[i]]))
# Out:
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.527590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.528590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.528590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.528590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.528590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.528590'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.529585'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.530582'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.530582'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.530582'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.530582'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.530582'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.531579'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.532577'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.532577'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.533575'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.533575'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.534573'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.534573'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.535570'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.535570'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.537563'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.538560'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.538560'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.519996, 'timestamp': '2023-07-21 00:21:35.538560'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 43.750000', 'action': 'buy', 'balance': 49.769996000000006, 'timestamp': '2023-07-21 00:21:35.539559'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 49.769996000000006, 'timestamp': '2023-07-21 00:21:35.540557'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 49.769996000000006, 'timestamp': '2023-07-21 00:21:35.540557'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.490002', 'action': 'buy', 'balance': 5.279994000000009, 'timestamp': '2023-07-21 00:21:35.541555'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 5.279994000000009, 'timestamp': '2023-07-21 00:21:35.542551'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.709999', 'investment': 2.1942834285714365, 'gain': 0.9599990000000034, 'balance': 49.98999300000001, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.543547'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 43.340000', 'action': 'buy', 'balance': 6.649993000000009, 'timestamp': '2023-07-21 00:21:35.543547'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 6.649993000000009, 'timestamp': '2023-07-21 00:21:35.544544'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 6.649993000000009, 'timestamp': '2023-07-21 00:21:35.544544'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 6.649993000000009, 'timestamp': '2023-07-21 00:21:35.545542'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 42.169998', 'investment': -5.214663735011739, 'gain': -2.3200039999999973, 'balance': 48.81999100000001, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.546540'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.220001', 'investment': 2.030459160129211, 'gain': 0.880001, 'balance': 93.03999200000001, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.546540'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.03999200000001, 'timestamp': '2023-07-21 00:21:35.547536'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.03999200000001, 'timestamp': '2023-07-21 00:21:35.547536'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 31.379999', 'action': 'buy', 'balance': 61.659993000000014, 'timestamp': '2023-07-21 00:21:35.548535'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.870001', 'investment': 1.5615105660137112, 'gain': 0.49000199999999694, 'balance': 93.52999400000002, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.549533'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.52999400000002, 'timestamp': '2023-07-21 00:21:35.549533'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 32.820000', 'action': 'buy', 'balance': 60.709994000000016, 'timestamp': '2023-07-21 00:21:35.550530'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.959999', 'investment': -2.6203564899451566, 'gain': -0.8600010000000005, 'balance': 92.66999300000002, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.551525'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 92.66999300000002, 'timestamp': '2023-07-21 00:21:35.551525'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 32.669998', 'action': 'buy', 'balance': 59.99999500000002, 'timestamp': '2023-07-21 00:21:35.552523'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.840000', 'investment': -2.540551119715403, 'gain': -0.8299979999999998, 'balance': 91.83999500000002, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.554519'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.554519'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.555514'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.556512'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.556512'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.557510'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.557510'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.558507'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.558507'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.83999500000002, 'timestamp': '2023-07-21 00:21:35.559504'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 33.810001', 'action': 'buy', 'balance': 58.029994000000016, 'timestamp': '2023-07-21 00:21:35.559504'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 33.880001', 'action': 'buy', 'balance': 24.149993000000016, 'timestamp': '2023-07-21 00:21:35.560503'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 34.279999', 'action': 'buy', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.560503'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.561499'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.561499'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.562525'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.562525'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.563496'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -10.13000599999998, 'timestamp': '2023-07-21 00:21:35.564491'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.730000', 'investment': -3.1943240699697193, 'gain': -1.0800010000000029, 'balance': 22.599994000000017, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.565488'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 30.809999', 'action': 'buy', 'balance': -8.210004999999985, 'timestamp': '2023-07-21 00:21:35.566488'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -8.210004999999985, 'timestamp': '2023-07-21 00:21:35.567515'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -8.210004999999985, 'timestamp': '2023-07-21 00:21:35.567515'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -8.210004999999985, 'timestamp': '2023-07-21 00:21:35.568481'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -8.210004999999985, 'timestamp': '2023-07-21 00:21:35.569478'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 30.389999', 'investment': -10.301068172931874, 'gain': -3.4900020000000005, 'balance': 22.179994000000015, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.572471'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 30.120001', 'investment': -12.135350412349775, 'gain': -4.159997999999998, 'balance': 52.29999500000001, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.573471'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 52.29999500000001, 'timestamp': '2023-07-21 00:21:35.573471'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 52.29999500000001, 'timestamp': '2023-07-21 00:21:35.574495'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.520000', 'investment': -4.186949178414454, 'gain': -1.2899990000000017, 'balance': 81.819995, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.575462'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.575462'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.576459'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.576459'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.577458'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.577458'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.578481'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.578481'}
# [0.00000000e+000 2.36331743e-260 1.00000000e+000]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 81.819995, 'timestamp': '2023-07-21 00:21:35.579450'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.190001', 'action': 'buy', 'balance': 53.62999400000001, 'timestamp': '2023-07-21 00:21:35.579450'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 53.62999400000001, 'timestamp': '2023-07-21 00:21:35.580448'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.230000', 'action': 'buy', 'balance': 25.39999400000001, 'timestamp': '2023-07-21 00:21:35.580448'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 25.39999400000001, 'timestamp': '2023-07-21 00:21:35.581446'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.450001', 'action': 'buy', 'balance': -3.05000699999999, 'timestamp': '2023-07-21 00:21:35.582443'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.270000', 'investment': 3.8311421131201833, 'gain': 1.0799990000000008, 'balance': 26.21999300000001, 'action': 'sell', 'timestamp': '2023-07-21 00:21:35.583441'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 26.21999300000001, 'timestamp': '2023-07-21 00:21:35.584439'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 27.000000', 'action': 'buy', 'balance': -0.7800069999999906, 'timestamp': '2023-07-21 00:21:35.584439'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': -0.7800069999999906, 'timestamp': '2023-07-21 00:21:35.585463'}

# %%
import copy
import pickle

copy_model = copy.deepcopy(agent.model)

with open('model.pkl', 'wb') as fopen:
    pickle.dump(copy_model, fopen)
