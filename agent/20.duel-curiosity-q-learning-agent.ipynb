# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        tf.compat.v1.disable_eager_execution()
        self.X = tf.compat.v1.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.compat.v1.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.compat.v1.placeholder(tf.float32, (None))
        self.REWARD = tf.compat.v1.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(input=self.ACTION)[0]
        
        with tf.compat.v1.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)
            
            feed = tf.compat.v1.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.compat.v1.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(input_tensor=tf.square(save_state - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(input_tensor=self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.compat.v1.variable_scope("q_model"):
            with tf.compat.v1.variable_scope("eval_net"):
                x_action = tf.compat.v1.layers.dense(self.X, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(x_action,2,1)
                feed_action = tf.compat.v1.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
                self.logits = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
            
            with tf.compat.v1.variable_scope("target_net"):
                y_action = tf.compat.v1.layers.dense(self.Y, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(y_action,2,1)
                feed_action = tf.compat.v1.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
                y_q = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(input_tensor=y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.compat.v1.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.compat.v1.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From c:\Users\joshu\miniconda3\Lib\site-packages\tensorflow\python\training\rmsprop.py:188: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:38: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed = tf.compat.v1.layers.dense(state_action, 32, activation=tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:39: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.curiosity_logits = tf.compat.v1.layers.dense(feed, self.state_size)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:49: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   x_action = tf.compat.v1.layers.dense(self.X, 128, tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:51: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, self.OUTPUT_SIZE)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:52: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:57: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_action = tf.compat.v1.layers.dense(self.Y, 128, tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:59: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, self.OUTPUT_SIZE)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15832\2278019460.py:60: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# epoch: 10, total rewards: 1603.090152.3, cost: 253412.468750, total money: 2018.290042
# epoch: 20, total rewards: 234.195127.3, cost: 7643286.500000, total money: 703.395138
# epoch: 30, total rewards: 422.739744.3, cost: 192756.250000, total money: 3636.399717
# epoch: 40, total rewards: 263.775084.3, cost: 2523010.500000, total money: 10263.775084
# epoch: 50, total rewards: 457.664798.3, cost: 391299.000000, total money: 1616.744753
# epoch: 60, total rewards: 1109.374878.3, cost: 1022172.250000, total money: 4176.154845
# epoch: 70, total rewards: 149.629825.3, cost: 89394.218750, total money: 3212.059818
# epoch: 80, total rewards: 890.110103.3, cost: 12783624.000000, total money: 4973.270075
# epoch: 90, total rewards: 1313.005184.3, cost: 1208406.500000, total money: 7325.575191
# epoch: 100, total rewards: 610.440069.3, cost: 583356.375000, total money: 1921.770085
# epoch: 110, total rewards: 818.655029.3, cost: 386768.093750, total money: 9801.545044
# epoch: 120, total rewards: 384.590090.3, cost: 1054845.500000, total money: 2662.390017
# epoch: 130, total rewards: 1227.875182.3, cost: 404176.468750, total money: 9245.385191
# epoch: 140, total rewards: 135.594786.3, cost: 1639916.500000, total money: 10135.594786
# epoch: 150, total rewards: 1788.779664.3, cost: 879915.000000, total money: 2119.609680
# epoch: 160, total rewards: 1580.940127.3, cost: 1098792.875000, total money: 7632.940126
# epoch: 170, total rewards: 1461.654970.3, cost: 798786.000000, total money: 6492.464906
# epoch: 180, total rewards: 783.325256.3, cost: 1226841.750000, total money: 10783.325256
# epoch: 190, total rewards: 765.059943.3, cost: 1906631.750000, total money: 10765.059943
# epoch: 200, total rewards: 240.554992.3, cost: 1248770.375000, total money: 9223.914977

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 2: buy 1 unit at price 762.020020, total balance 9237.979980
# day 3, sell 1 unit at price 782.520020, investment 2.690218 %, total balance 10020.500000,
# day 6: buy 1 unit at price 762.559998, total balance 9257.940002
# day 8, sell 1 unit at price 736.080017, investment -3.472511 %, total balance 9994.020019,
# day 13: buy 1 unit at price 769.200012, total balance 9224.820007
# day 14: buy 1 unit at price 768.270020, total balance 8456.549987
# day 17: buy 1 unit at price 768.239990, total balance 7688.309997
# day 19: buy 1 unit at price 758.039978, total balance 6930.270019
# day 20: buy 1 unit at price 747.919983, total balance 6182.350036
# day 21: buy 1 unit at price 750.500000, total balance 5431.850036
# day 22, sell 1 unit at price 762.520020, investment -0.868434 %, total balance 6194.370056,
# day 23, sell 1 unit at price 759.109985, investment -1.192294 %, total balance 6953.480041,
# day 24, sell 1 unit at price 771.190002, investment 0.383996 %, total balance 7724.670043,
# day 25: buy 1 unit at price 776.419983, total balance 6948.250060
# day 26: buy 1 unit at price 789.289978, total balance 6158.960082
# day 28: buy 1 unit at price 796.099976, total balance 5362.860106
# day 29: buy 1 unit at price 797.070007, total balance 4565.790099
# day 30, sell 1 unit at price 797.849976, investment 5.251702 %, total balance 5363.640075,
# day 31, sell 1 unit at price 790.799988, investment 5.733234 %, total balance 6154.440063,
# day 32: buy 1 unit at price 794.200012, total balance 5360.240051
# day 33: buy 1 unit at price 796.419983, total balance 4563.820068
# day 34, sell 1 unit at price 794.559998, investment 5.870753 %, total balance 5358.380066,
# day 35, sell 1 unit at price 791.260010, investment 1.911340 %, total balance 6149.640076,
# day 36: buy 1 unit at price 789.909973, total balance 5359.730103
# day 39, sell 1 unit at price 782.789978, investment -0.823525 %, total balance 6142.520081,
# day 42, sell 1 unit at price 786.900024, investment -1.155628 %, total balance 6929.420105,
# day 45: buy 1 unit at price 806.650024, total balance 6122.770081
# day 46: buy 1 unit at price 804.789978, total balance 5317.980103
# day 47: buy 1 unit at price 807.909973, total balance 4510.070130
# day 48: buy 1 unit at price 806.359985, total balance 3703.710145
# day 49: buy 1 unit at price 807.880005, total balance 2895.830140
# day 51: buy 1 unit at price 806.070007, total balance 2089.760133
# day 52, sell 1 unit at price 802.174988, investment 0.640468 %, total balance 2891.935121,
# day 54, sell 1 unit at price 819.309998, investment 3.161670 %, total balance 3711.245119,
# day 55, sell 1 unit at price 823.869995, investment 3.446675 %, total balance 4535.115114,
# day 57: buy 1 unit at price 832.150024, total balance 3702.965090
# day 58: buy 1 unit at price 823.309998, total balance 2879.655092
# day 59: buy 1 unit at price 802.320007, total balance 2077.335085
# day 60: buy 1 unit at price 796.789978, total balance 1280.545107
# day 61: buy 1 unit at price 795.695007, total balance 484.850100
# day 62, sell 1 unit at price 798.530029, investment 1.091271 %, total balance 1283.380129,
# day 64: buy 1 unit at price 801.340027, total balance 482.040102
# day 66, sell 1 unit at price 808.380005, investment 0.214465 %, total balance 1290.420107,
# day 67: buy 1 unit at price 809.559998, total balance 480.860109
# day 68, sell 1 unit at price 813.669983, investment 1.103394 %, total balance 1294.530092,
# day 70: buy 1 unit at price 820.450012, total balance 474.080080
# day 74, sell 1 unit at price 831.659973, investment 2.939684 %, total balance 1305.740053,
# day 75, sell 1 unit at price 830.760010, investment 3.025947 %, total balance 2136.500063,
# day 76: buy 1 unit at price 831.330017, total balance 1305.170046
# day 77: buy 1 unit at price 828.640015, total balance 476.530031
# day 83, sell 1 unit at price 827.780029, investment 2.463240 %, total balance 1304.310060,
# day 84, sell 1 unit at price 831.909973, investment 3.205673 %, total balance 2136.220033,
# day 86, sell 1 unit at price 838.679993, investment 0.784711 %, total balance 2974.900026,
# day 87: buy 1 unit at price 843.250000, total balance 2131.650026
# day 88, sell 1 unit at price 845.539978, investment 2.700074 %, total balance 2977.190004,
# day 90, sell 1 unit at price 847.200012, investment 5.593779 %, total balance 3824.390016,
# day 91: buy 1 unit at price 848.780029, total balance 2975.609987
# day 92, sell 1 unit at price 852.119995, investment 6.944116 %, total balance 3827.729982,
# day 93: buy 1 unit at price 848.400024, total balance 2979.329958
# day 94, sell 1 unit at price 830.460022, investment 4.369138 %, total balance 3809.789980,
# day 95: buy 1 unit at price 829.590027, total balance 2980.199953
# day 96, sell 1 unit at price 817.580017, investment 2.026604 %, total balance 3797.779970,
# day 101, sell 1 unit at price 831.500000, investment 2.710114 %, total balance 4629.279970,
# day 102, sell 1 unit at price 829.559998, investment 1.110365 %, total balance 5458.839968,
# day 103, sell 1 unit at price 838.549988, investment 0.868484 %, total balance 6297.389956,
# day 104, sell 1 unit at price 834.570007, investment 0.715629 %, total balance 7131.959963,
# day 105: buy 1 unit at price 831.409973, total balance 6300.549990
# day 107, sell 1 unit at price 824.669983, investment -2.203382 %, total balance 7125.219973,
# day 108: buy 1 unit at price 824.729980, total balance 6300.489993
# day 110: buy 1 unit at price 824.320007, total balance 5476.169986
# day 112, sell 1 unit at price 837.169983, investment -1.367851 %, total balance 6313.339969,
# day 113, sell 1 unit at price 836.820007, investment -1.364924 %, total balance 7150.159976,
# day 115: buy 1 unit at price 841.650024, total balance 6308.509952
# day 116: buy 1 unit at price 843.190002, total balance 5465.319950
# day 117: buy 1 unit at price 862.760010, total balance 4602.559940
# day 118: buy 1 unit at price 872.299988, total balance 3730.259952
# day 119: buy 1 unit at price 871.729980, total balance 2858.529972
# day 120, sell 1 unit at price 874.250000, investment 5.383379 %, total balance 3732.779972,
# day 121, sell 1 unit at price 905.960022, investment 8.966701 %, total balance 4638.739994,
# day 122, sell 1 unit at price 912.570007, investment 10.650762 %, total balance 5551.310001,
# day 125, sell 1 unit at price 931.659973, investment 13.021638 %, total balance 6482.969974,
# day 127, sell 1 unit at price 934.299988, investment 11.008134 %, total balance 7417.269962,
# day 129: buy 1 unit at price 928.780029, total balance 6488.489933
# day 131: buy 1 unit at price 932.219971, total balance 5556.269962
# day 132: buy 1 unit at price 937.080017, total balance 4619.189945
# day 133: buy 1 unit at price 943.000000, total balance 3676.189945
# day 136, sell 1 unit at price 934.010010, investment 10.771002 %, total balance 4610.199955,
# day 137, sell 1 unit at price 941.859985, investment 9.168248 %, total balance 5552.059940,
# day 138, sell 1 unit at price 948.820007, investment 8.772214 %, total balance 6500.879947,
# day 139, sell 1 unit at price 954.960022, investment 9.547686 %, total balance 7455.839969,
# day 141, sell 1 unit at price 971.469971, investment 4.596346 %, total balance 8427.309940,
# day 142: buy 1 unit at price 975.880005, total balance 7451.429935
# day 143, sell 1 unit at price 964.859985, investment 3.501321 %, total balance 8416.289920,
# day 145: buy 1 unit at price 975.599976, total balance 7440.689944
# day 146, sell 1 unit at price 983.679993, investment 4.972892 %, total balance 8424.369937,
# day 148, sell 1 unit at price 980.940002, investment 4.023330 %, total balance 9405.309939,
# day 150: buy 1 unit at price 949.830017, total balance 8455.479922
# day 152: buy 1 unit at price 953.400024, total balance 7502.079898
# day 153, sell 1 unit at price 950.760010, investment -2.574086 %, total balance 8452.839908,
# day 155, sell 1 unit at price 939.780029, investment -3.671581 %, total balance 9392.619937,
# day 156: buy 1 unit at price 957.369995, total balance 8435.249942
# day 157, sell 1 unit at price 950.630005, investment 0.084224 %, total balance 9385.879947,
# day 158, sell 1 unit at price 959.450012, investment 0.634570 %, total balance 10345.329959,
# day 159, sell 1 unit at price 957.090027, investment -0.029243 %, total balance 11302.419986,
# day 161: buy 1 unit at price 952.270020, total balance 10350.149966
# day 165: buy 1 unit at price 908.729980, total balance 9441.419986
# day 166, sell 1 unit at price 898.700012, investment -5.625506 %, total balance 10340.119998,
# day 168, sell 1 unit at price 906.690002, investment -0.224487 %, total balance 11246.810000,
# day 172: buy 1 unit at price 943.830017, total balance 10302.979983
# day 173, sell 1 unit at price 947.159973, investment 0.352813 %, total balance 11250.139956,
# day 175: buy 1 unit at price 953.419983, total balance 10296.719973
# day 176, sell 1 unit at price 965.400024, investment 1.256533 %, total balance 11262.119997,
# day 177: buy 1 unit at price 970.890015, total balance 10291.229982
# day 179, sell 1 unit at price 972.919983, investment 0.209083 %, total balance 11264.149965,
# day 181: buy 1 unit at price 950.700012, total balance 10313.449953
# day 182, sell 1 unit at price 947.799988, investment -0.305041 %, total balance 11261.249941,
# day 184: buy 1 unit at price 941.530029, total balance 10319.719912
# day 187: buy 1 unit at price 930.390015, total balance 9389.329897
# day 188, sell 1 unit at price 923.650024, investment -1.899037 %, total balance 10312.979921,
# day 191: buy 1 unit at price 926.789978, total balance 9386.189943
# day 192: buy 1 unit at price 922.900024, total balance 8463.289919
# day 193, sell 1 unit at price 907.239990, investment -2.488207 %, total balance 9370.529909,
# day 195, sell 1 unit at price 922.669983, investment -0.444545 %, total balance 10293.199892,
# day 196, sell 1 unit at price 922.219971, investment -0.073687 %, total balance 11215.419863,
# day 198: buy 1 unit at price 910.979980, total balance 10304.439883
# day 199: buy 1 unit at price 910.669983, total balance 9393.769900
# day 200, sell 1 unit at price 906.659973, investment -0.474215 %, total balance 10300.429873,
# day 201, sell 1 unit at price 924.690002, investment 1.539528 %, total balance 11225.119875,
# day 203: buy 1 unit at price 921.280029, total balance 10303.839846
# day 204: buy 1 unit at price 915.890015, total balance 9387.949831
# day 205, sell 1 unit at price 913.809998, investment -0.810832 %, total balance 10301.759829,
# day 206, sell 1 unit at price 921.289978, investment 0.589586 %, total balance 11223.049807,
# day 207: buy 1 unit at price 929.570007, total balance 10293.479800
# day 208, sell 1 unit at price 939.330017, investment 1.049949 %, total balance 11232.809817,
# day 211: buy 1 unit at price 927.809998, total balance 10304.999819
# day 212, sell 1 unit at price 935.950012, investment 0.877336 %, total balance 11240.949831,
# day 213: buy 1 unit at price 926.500000, total balance 10314.449831
# day 214, sell 1 unit at price 929.080017, investment 0.278469 %, total balance 11243.529848,
# day 216: buy 1 unit at price 935.090027, total balance 10308.439821
# day 218: buy 1 unit at price 920.289978, total balance 9388.149843
# day 220: buy 1 unit at price 921.809998, total balance 8466.339845
# day 221, sell 1 unit at price 931.580017, investment -0.375366 %, total balance 9397.919862,
# day 223: buy 1 unit at price 928.530029, total balance 8469.389833
# day 224: buy 1 unit at price 920.969971, total balance 7548.419862
# day 225, sell 1 unit at price 924.859985, investment 0.496583 %, total balance 8473.279847,
# day 226, sell 1 unit at price 944.489990, investment 2.460376 %, total balance 9417.769837,
# day 230: buy 1 unit at price 957.789978, total balance 8459.979859
# day 232, sell 1 unit at price 969.960022, investment 4.461890 %, total balance 9429.939881,
# day 234, sell 1 unit at price 977.000000, investment 6.083806 %, total balance 10406.939881,
# day 235: buy 1 unit at price 972.599976, total balance 9434.339905
# day 237: buy 1 unit at price 987.830017, total balance 8446.509888
# day 238: buy 1 unit at price 989.679993, total balance 7456.829895
# day 240, sell 1 unit at price 992.179993, investment 3.590559 %, total balance 8449.009888,
# day 242, sell 1 unit at price 984.450012, investment 1.218387 %, total balance 9433.459900,
# day 243, sell 1 unit at price 988.200012, investment 0.037455 %, total balance 10421.659912,
# day 244: buy 1 unit at price 968.450012, total balance 9453.209900
# day 246: buy 1 unit at price 973.330017, total balance 8479.879883
# day 247, sell 1 unit at price 972.559998, investment -1.729852 %, total balance 9452.439881,
# day 248, sell 1 unit at price 1019.270020, investment 5.247561 %, total balance 10471.709901,
# day 249, sell 1 unit at price 1017.109985, investment 4.497957 %, total balance 11488.819886,
# day 250: buy 1 unit at price 1016.640015, total balance 10472.179871

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
