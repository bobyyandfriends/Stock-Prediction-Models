# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.compat.v1.reset_default_graph()
        self.sess = tf.compat.v1.InteractiveSession()
        tf.compat.v1.disable_eager_execution()
        self.X = tf.compat.v1.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.compat.v1.placeholder(tf.float32, [None, self.action_size])
        feed = tf.compat.v1.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.compat.v1.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(input_tensor=tf.square(self.Y - self.logits))
        self.optimizer = tf.compat.v1.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.compat.v1.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15688\2234106587.py:27: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed = tf.compat.v1.layers.dense(self.X, 256, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_15688\2234106587.py:28: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed, self.action_size)
# epoch: 10, total rewards: 2238.310238.3, cost: 0.774864, total money: 4739.490170
# epoch: 20, total rewards: 2426.270015.3, cost: 0.338137, total money: 4967.719967
# epoch: 30, total rewards: 2384.620051.3, cost: 0.238441, total money: 4926.070003
# epoch: 40, total rewards: 2427.100032.3, cost: 0.213499, total money: 7783.409969
# epoch: 50, total rewards: 2496.360042.3, cost: 0.156987, total money: 6936.090023
# epoch: 60, total rewards: 2361.810116.3, cost: 0.139420, total money: 7722.830075
# epoch: 70, total rewards: 2317.390133.3, cost: 0.114177, total money: 7678.410092
# epoch: 80, total rewards: 2444.840021.3, cost: 0.163315, total money: 7786.229975
# epoch: 90, total rewards: 2545.570003.3, cost: 0.083679, total money: 6985.299984
# epoch: 100, total rewards: 2401.040095.3, cost: 0.291653, total money: 6789.460078
# epoch: 110, total rewards: 2369.570126.3, cost: 0.072646, total money: 7730.590085
# epoch: 120, total rewards: 2426.369991.3, cost: 0.058694, total money: 6866.099972
# epoch: 130, total rewards: 2462.189938.3, cost: 0.053107, total money: 6901.919919
# epoch: 140, total rewards: 2617.270015.3, cost: 0.971744, total money: 7978.289974
# epoch: 150, total rewards: 2456.544857.3, cost: 0.043303, total money: 6896.274838
# epoch: 160, total rewards: 2454.849910.3, cost: 0.039449, total money: 6894.579891
# epoch: 170, total rewards: 2468.649897.3, cost: 0.036427, total money: 6908.379878
# epoch: 180, total rewards: 2348.139951.3, cost: 0.036816, total money: 7709.159910
# epoch: 190, total rewards: 2504.349847.3, cost: 0.171162, total money: 6944.079828
# epoch: 200, total rewards: 2401.630001.3, cost: 0.029305, total money: 7762.649960

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2: buy 1 unit at price 762.020020, total balance 8475.849975
# day 3, sell 1 unit at price 782.520020, investment 2.675399 %, total balance 9258.369995,
# day 4: buy 1 unit at price 790.510010, total balance 8467.859985
# day 5: buy 1 unit at price 785.309998, total balance 7682.549987
# day 7, sell 1 unit at price 754.020020, investment -1.049841 %, total balance 8436.570007,
# day 8: buy 1 unit at price 736.080017, total balance 7700.489990
# day 9: buy 1 unit at price 758.489990, total balance 6942.000000
# day 10: buy 1 unit at price 764.479980, total balance 6177.520020
# day 11: buy 1 unit at price 771.229980, total balance 5406.290040
# day 13, sell 1 unit at price 769.200012, investment -2.695728 %, total balance 6175.490052,
# day 14: buy 1 unit at price 768.270020, total balance 5407.220032
# day 16: buy 1 unit at price 761.679993, total balance 4645.540039
# day 17, sell 1 unit at price 768.239990, investment -2.173665 %, total balance 5413.780029,
# day 19, sell 1 unit at price 758.039978, investment 2.983366 %, total balance 6171.820007,
# day 22: buy 1 unit at price 762.520020, total balance 5409.299987
# day 23, sell 1 unit at price 759.109985, investment 0.081741 %, total balance 6168.409972,
# day 25, sell 1 unit at price 776.419983, investment 1.561846 %, total balance 6944.829955,
# day 26: buy 1 unit at price 789.289978, total balance 6155.539977
# day 27: buy 1 unit at price 789.270020, total balance 5366.269957
# day 29, sell 1 unit at price 797.070007, investment 3.350496 %, total balance 6163.339964,
# day 30: buy 1 unit at price 797.849976, total balance 5365.489988
# day 31: buy 1 unit at price 790.799988, total balance 4574.690000
# day 32, sell 1 unit at price 794.200012, investment 3.375114 %, total balance 5368.890012,
# day 33: buy 1 unit at price 796.419983, total balance 4572.470029
# day 36: buy 1 unit at price 789.909973, total balance 3782.560056
# day 37: buy 1 unit at price 791.549988, total balance 2991.010068
# day 38, sell 1 unit at price 785.049988, investment 3.068217 %, total balance 3776.060056,
# day 40: buy 1 unit at price 771.820007, total balance 3004.240049
# day 41: buy 1 unit at price 786.140015, total balance 2218.100034
# day 42: buy 1 unit at price 786.900024, total balance 1431.200010
# day 44, sell 1 unit at price 806.150024, investment 5.721818 %, total balance 2237.350034,
# day 45: buy 1 unit at price 806.650024, total balance 1430.700010
# day 46: buy 1 unit at price 804.789978, total balance 625.910032
# day 51, sell 1 unit at price 806.070007, investment 2.125965 %, total balance 1431.980039,
# day 52: buy 1 unit at price 802.174988, total balance 629.805051
# day 53, sell 1 unit at price 805.020020, investment 1.995515 %, total balance 1434.825071,
# day 55, sell 1 unit at price 823.869995, investment 3.261267 %, total balance 2258.695066,
# day 57, sell 1 unit at price 832.150024, investment 5.228887 %, total balance 3090.845090,
# day 58, sell 1 unit at price 823.309998, investment 3.376361 %, total balance 3914.155088,
# day 59: buy 1 unit at price 802.320007, total balance 3111.835081
# day 60, sell 1 unit at price 796.789978, investment 0.870986 %, total balance 3908.625059,
# day 61: buy 1 unit at price 795.695007, total balance 3112.930052
# day 62, sell 1 unit at price 798.530029, investment 0.881819 %, total balance 3911.460081,
# day 64, sell 1 unit at price 801.340027, investment 3.824729 %, total balance 4712.800108,
# day 65: buy 1 unit at price 806.969971, total balance 3905.830137
# day 66: buy 1 unit at price 808.380005, total balance 3097.450132
# day 67: buy 1 unit at price 809.559998, total balance 2287.890134
# day 68: buy 1 unit at price 813.669983, total balance 1474.220151
# day 69: buy 1 unit at price 819.239990, total balance 654.980161
# day 70, sell 1 unit at price 820.450012, investment 4.364362 %, total balance 1475.430173,
# day 72, sell 1 unit at price 824.159973, investment 4.735030 %, total balance 2299.590146,
# day 73: buy 1 unit at price 828.070007, total balance 1471.520139
# day 74: buy 1 unit at price 831.659973, total balance 639.860166
# day 77, sell 1 unit at price 828.640015, investment 2.726088 %, total balance 1468.500181,
# day 78: buy 1 unit at price 829.280029, total balance 639.220152
# day 81, sell 1 unit at price 830.630005, investment 3.210779 %, total balance 1469.850157,
# day 82: buy 1 unit at price 829.080017, total balance 640.770140
# day 83, sell 1 unit at price 827.780029, investment 3.191952 %, total balance 1468.550169,
# day 84: buy 1 unit at price 831.909973, total balance 636.640196
# day 93, sell 1 unit at price 848.400024, investment 5.743346 %, total balance 1485.040220,
# day 94: buy 1 unit at price 830.460022, total balance 654.580198
# day 96, sell 1 unit at price 817.580017, investment 2.750427 %, total balance 1472.160215,
# day 97: buy 1 unit at price 814.429993, total balance 657.730222
# day 98, sell 1 unit at price 819.510010, investment 1.553966 %, total balance 1477.240232,
# day 99: buy 1 unit at price 820.919983, total balance 656.320249
# day 100, sell 1 unit at price 831.409973, investment 2.848904 %, total balance 1487.730222,
# day 101: buy 1 unit at price 831.500000, total balance 656.230222
# day 109, sell 1 unit at price 823.349976, investment 1.703392 %, total balance 1479.580198,
# day 111, sell 1 unit at price 823.559998, investment 1.215482 %, total balance 2303.140196,
# day 112: buy 1 unit at price 837.169983, total balance 1465.970213
# day 113: buy 1 unit at price 836.820007, total balance 629.150206
# day 121, sell 1 unit at price 905.960022, investment 10.585425 %, total balance 1535.110228,
# day 122: buy 1 unit at price 912.570007, total balance 622.540221
# day 131, sell 1 unit at price 932.219971, investment 12.577435 %, total balance 1554.760192,
# day 134: buy 1 unit at price 919.619995, total balance 635.140197
# day 135, sell 1 unit at price 930.239990, investment 11.853404 %, total balance 1565.380187,
# day 136: buy 1 unit at price 934.010010, total balance 631.370177
# day 137, sell 1 unit at price 941.859985, investment 13.575626 %, total balance 1573.230162,
# day 143, sell 1 unit at price 964.859985, investment 16.377185 %, total balance 2538.090147,
# day 144, sell 1 unit at price 966.950012, investment 16.232530 %, total balance 3505.040159,
# day 145, sell 1 unit at price 975.599976, investment 17.477055 %, total balance 4480.640135,
# day 146, sell 1 unit at price 983.679993, investment 20.781406 %, total balance 5464.320128,
# day 148, sell 1 unit at price 980.940002, investment 19.492767 %, total balance 6445.260130,
# day 149, sell 1 unit at price 983.409973, investment 18.269389 %, total balance 7428.670103,
# day 150: buy 1 unit at price 949.830017, total balance 6478.840086
# day 151: buy 1 unit at price 942.900024, total balance 5535.940062
# day 152, sell 1 unit at price 953.400024, investment 13.883685 %, total balance 6489.340086,
# day 153: buy 1 unit at price 950.760010, total balance 5538.580076
# day 154: buy 1 unit at price 942.309998, total balance 4596.270078
# day 155: buy 1 unit at price 939.780029, total balance 3656.490049
# day 156, sell 1 unit at price 957.369995, investment 14.405725 %, total balance 4613.860044,
# day 158, sell 1 unit at price 959.450012, investment 5.137141 %, total balance 5573.310056,
# day 159: buy 1 unit at price 957.090027, total balance 4616.220029
# day 160: buy 1 unit at price 965.590027, total balance 3650.630002
# day 162: buy 1 unit at price 927.330017, total balance 2723.299985
# day 164: buy 1 unit at price 917.789978, total balance 1805.510007
# day 165: buy 1 unit at price 908.729980, total balance 896.780027
# day 169, sell 1 unit at price 918.590027, investment -0.111999 %, total balance 1815.370054,
# day 170: buy 1 unit at price 928.799988, total balance 886.570066
# day 174, sell 1 unit at price 955.989990, investment 2.353292 %, total balance 1842.560056,
# day 175: buy 1 unit at price 953.419983, total balance 889.140073
# day 177, sell 1 unit at price 970.890015, investment 2.217239 %, total balance 1860.030088,
# day 179, sell 1 unit at price 972.919983, investment 3.183790 %, total balance 2832.950071,
# day 180: buy 1 unit at price 980.340027, total balance 1852.610044
# day 181: buy 1 unit at price 950.700012, total balance 901.910032
# day 186, sell 1 unit at price 930.830017, investment -2.096217 %, total balance 1832.740049,
# day 187: buy 1 unit at price 930.390015, total balance 902.350034
# day 192, sell 1 unit at price 922.900024, investment -2.059829 %, total balance 1825.250058,
# day 193: buy 1 unit at price 907.239990, total balance 918.010068
# day 194: buy 1 unit at price 914.390015, total balance 3.620053
# day 200, sell 1 unit at price 906.659973, investment -3.524235 %, total balance 910.280026,
# day 202, sell 1 unit at price 927.000000, investment -3.143908 %, total balance 1837.280026,
# day 203: buy 1 unit at price 921.280029, total balance 915.999997
# day 205, sell 1 unit at price 913.809998, investment -5.362527 %, total balance 1829.809995,
# day 206: buy 1 unit at price 921.289978, total balance 908.520017
# day 215, sell 1 unit at price 932.070007, investment 0.511144 %, total balance 1840.590024,
# day 216: buy 1 unit at price 935.090027, total balance 905.499997
# day 217, sell 1 unit at price 925.109985, investment 0.797569 %, total balance 1830.609982,
# day 218, sell 1 unit at price 920.289978, investment 1.272105 %, total balance 2750.899960,
# day 219: buy 1 unit at price 915.000000, total balance 1835.899960
# day 220, sell 1 unit at price 921.809998, investment -0.752583 %, total balance 2757.709958,
# day 221: buy 1 unit at price 931.580017, total balance 1826.129941
# day 222: buy 1 unit at price 932.450012, total balance 893.679929
# day 224, sell 1 unit at price 920.969971, investment -3.403538 %, total balance 1814.649900,
# day 225, sell 1 unit at price 924.859985, investment -5.659265 %, total balance 2739.509885,
# day 226: buy 1 unit at price 944.489990, total balance 1795.019895
# day 227: buy 1 unit at price 949.500000, total balance 845.519895
# day 228, sell 1 unit at price 959.109985, investment 0.884608 %, total balance 1804.629880,
# day 230, sell 1 unit at price 957.789978, investment 2.944998 %, total balance 2762.419858,
# day 234, sell 1 unit at price 977.000000, investment 7.689257 %, total balance 3739.419858,
# day 236, sell 1 unit at price 989.250000, investment 8.186877 %, total balance 4728.669858,
# day 242, sell 1 unit at price 984.450012, investment 6.856762 %, total balance 5713.119870,
# day 246, sell 1 unit at price 973.330017, investment 5.648606 %, total balance 6686.449887,
# day 248, sell 1 unit at price 1019.270020, investment 9.002341 %, total balance 7705.719907,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
