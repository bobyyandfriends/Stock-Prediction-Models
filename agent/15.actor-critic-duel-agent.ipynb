# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.compat.v1.variable_scope(name):
            tf.compat.v1.disable_eager_execution()
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_actor,2,1)
            feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
            feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.compat.v1.variable_scope(name):
            tf.compat.v1.disable_eager_execution()
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.compat.v1.placeholder(tf.float32, (None, 1))
            feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_critic,2,1)
            feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
            feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(input_tensor=tf.square(self.REWARD - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(ys=self.critic.logits, xs=self.critic.Y)
        self.actor_critic_grad = tf.compat.v1.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(ys=self.actor.logits, xs=weights_actor, grad_ys=-self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.compat.v1.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:9: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:11: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:12: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:23: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:25: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:26: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:29: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_9828\35230399.py:30: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
# epoch: 10, total rewards: 864.759705.3, cost: 0.117772, total money: 5060.989747
# epoch: 20, total rewards: 392.505006.3, cost: 0.093086, total money: 8400.674988
# epoch: 30, total rewards: 568.499816.3, cost: 984.559021, total money: 889.569884
# epoch: 40, total rewards: 628.900021.3, cost: 5982.230469, total money: 9609.630001
# epoch: 50, total rewards: 644.675477.3, cost: 256320.125000, total money: 4036.165466
# epoch: 60, total rewards: 956.089965.3, cost: 401696.406250, total money: 8030.629943
# epoch: 70, total rewards: 721.959777.3, cost: 2039432576.000000, total money: 1291.069702
# epoch: 80, total rewards: 2024.565125.3, cost: 106597.968750, total money: 5258.735108
# epoch: 90, total rewards: 1140.140439.3, cost: 126762.765625, total money: 833.480344
# epoch: 100, total rewards: 2356.535279.3, cost: 72404.367188, total money: 132.255190
# epoch: 110, total rewards: 1882.474854.3, cost: 173735.843750, total money: 542.644835
# epoch: 120, total rewards: 1728.155143.3, cost: 66136.781250, total money: 545.705071
# epoch: 130, total rewards: 1502.975157.3, cost: 60647.343750, total money: 1127.085143
# epoch: 140, total rewards: 1648.944879.3, cost: 58573.335938, total money: 257.704827
# epoch: 150, total rewards: 1696.550108.3, cost: 66637.765625, total money: 1140.090024
# epoch: 160, total rewards: 2026.054870.3, cost: 42915.132812, total money: 1502.624754
# epoch: 170, total rewards: 1919.939753.3, cost: 16641.195312, total money: 477.839777
# epoch: 180, total rewards: 1877.195248.3, cost: 4004.075195, total money: 1356.845273
# epoch: 190, total rewards: 2385.935300.3, cost: 35948.910156, total money: 101.275265
# epoch: 200, total rewards: 2275.095095.3, cost: 9617.843750, total money: 24.815066

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1: buy 1 unit at price 762.130005, total balance 8469.169983
# day 2, sell 1 unit at price 762.020020, investment -0.868999 %, total balance 9231.190003,
# day 3, sell 1 unit at price 782.520020, investment 2.675399 %, total balance 10013.710023,
# day 4: buy 1 unit at price 790.510010, total balance 9223.200013
# day 5: buy 1 unit at price 785.309998, total balance 8437.890015
# day 8: buy 1 unit at price 736.080017, total balance 7701.809998
# day 9: buy 1 unit at price 758.489990, total balance 6943.320008
# day 10: buy 1 unit at price 764.479980, total balance 6178.840028
# day 11: buy 1 unit at price 771.229980, total balance 5407.610048
# day 12: buy 1 unit at price 760.539978, total balance 4647.070070
# day 14: buy 1 unit at price 768.270020, total balance 3878.800050
# day 15, sell 1 unit at price 760.989990, investment -3.734301 %, total balance 4639.790040,
# day 17: buy 1 unit at price 768.239990, total balance 3871.550050
# day 18: buy 1 unit at price 770.840027, total balance 3100.710023
# day 21: buy 1 unit at price 750.500000, total balance 2350.210023
# day 22: buy 1 unit at price 762.520020, total balance 1587.690003
# day 23: buy 1 unit at price 759.109985, total balance 828.580018
# day 24: buy 1 unit at price 771.190002, total balance 57.390016
# day 27, sell 1 unit at price 789.270020, investment 0.504262 %, total balance 846.660036,
# day 28: buy 1 unit at price 796.099976, total balance 50.560060
# day 31, sell 1 unit at price 790.799988, investment 7.433970 %, total balance 841.360048,
# day 32: buy 1 unit at price 794.200012, total balance 47.160036
# day 37, sell 1 unit at price 791.549988, investment 4.358660 %, total balance 838.710024,
# day 39, sell 1 unit at price 782.789978, investment 2.395092 %, total balance 1621.500002,
# day 41: buy 1 unit at price 786.140015, total balance 835.359987
# day 43: buy 1 unit at price 794.020020, total balance 41.339967
# day 60, sell 1 unit at price 796.789978, investment 3.314186 %, total balance 838.129945,
# day 61: buy 1 unit at price 795.695007, total balance 42.434938
# day 64, sell 1 unit at price 801.340027, investment 5.364616 %, total balance 843.774965,
# day 65: buy 1 unit at price 806.969971, total balance 36.804994
# day 66, sell 1 unit at price 808.380005, investment 5.220819 %, total balance 845.184999,
# day 67: buy 1 unit at price 809.559998, total balance 35.625001
# day 78, sell 1 unit at price 829.280029, investment 7.945439 %, total balance 864.905030,
# day 79: buy 1 unit at price 823.210022, total balance 41.695008
# day 80, sell 1 unit at price 835.239990, investment 8.354517 %, total balance 876.934998,
# day 82, sell 1 unit at price 829.080017, investment 10.470355 %, total balance 1706.015015,
# day 83, sell 1 unit at price 827.780029, investment 8.558465 %, total balance 2533.795044,
# day 86: buy 1 unit at price 838.679993, total balance 1695.115051
# day 87: buy 1 unit at price 843.250000, total balance 851.865051
# day 88: buy 1 unit at price 845.539978, total balance 6.325073
# day 89, sell 1 unit at price 845.619995, investment 11.396242 %, total balance 851.945068,
# day 90: buy 1 unit at price 847.200012, total balance 4.745056
# day 92, sell 1 unit at price 852.119995, investment 10.494170 %, total balance 856.865051,
# day 93: buy 1 unit at price 848.400024, total balance 8.465027
# day 94, sell 1 unit at price 830.460022, investment 4.316047 %, total balance 838.925049,
# day 95: buy 1 unit at price 829.590027, total balance 9.335022
# day 98, sell 1 unit at price 819.510010, investment 3.186854 %, total balance 828.845032,
# day 99: buy 1 unit at price 820.919983, total balance 7.925049
# day 100, sell 1 unit at price 831.409973, investment 5.758511 %, total balance 839.335022,
# day 101: buy 1 unit at price 831.500000, total balance 7.835022
# day 118, sell 1 unit at price 872.299988, investment 9.858689 %, total balance 880.135010,
# day 119: buy 1 unit at price 871.729980, total balance 8.405030
# day 132, sell 1 unit at price 937.080017, investment 17.768744 %, total balance 945.485047,
# day 133: buy 1 unit at price 943.000000, total balance 2.485047
# day 134, sell 1 unit at price 919.619995, investment 13.959630 %, total balance 922.105042,
# day 138, sell 1 unit at price 948.820007, investment 17.201938 %, total balance 1870.925049,
# day 139: buy 1 unit at price 954.960022, total balance 915.965027
# day 142, sell 1 unit at price 975.880005, investment 18.545691 %, total balance 1891.845032,
# day 143, sell 1 unit at price 964.859985, investment 15.045070 %, total balance 2856.705017,
# day 145: buy 1 unit at price 975.599976, total balance 1881.105041
# day 146: buy 1 unit at price 983.679993, total balance 897.425048
# day 152, sell 1 unit at price 953.400024, investment 13.062558 %, total balance 1850.825072,
# day 153: buy 1 unit at price 950.760010, total balance 900.065062
# day 155, sell 1 unit at price 939.780029, investment 11.145546 %, total balance 1839.845091,
# day 157, sell 1 unit at price 950.630005, investment 12.208450 %, total balance 2790.475096,
# day 158: buy 1 unit at price 959.450012, total balance 1831.025084
# day 159, sell 1 unit at price 957.090027, investment 12.811174 %, total balance 2788.115111,
# day 160: buy 1 unit at price 965.590027, total balance 1822.525084
# day 161: buy 1 unit at price 952.270020, total balance 870.255064
# day 163, sell 1 unit at price 940.489990, investment 13.368044 %, total balance 1810.745054,
# day 164: buy 1 unit at price 917.789978, total balance 892.955076
# day 166, sell 1 unit at price 898.700012, investment 9.474739 %, total balance 1791.655088,
# day 167, sell 1 unit at price 911.710022, investment 9.646425 %, total balance 2703.365110,
# day 168, sell 1 unit at price 906.690002, investment 4.010419 %, total balance 3610.055112,
# day 169: buy 1 unit at price 918.590027, total balance 2691.465085
# day 170: buy 1 unit at price 928.799988, total balance 1762.665097
# day 171, sell 1 unit at price 930.090027, investment -1.369032 %, total balance 2692.755124,
# day 172: buy 1 unit at price 943.830017, total balance 1748.925107
# day 173, sell 1 unit at price 947.159973, investment -0.816793 %, total balance 2696.085080,
# day 175, sell 1 unit at price 953.419983, investment -2.273472 %, total balance 3649.505063,
# day 176: buy 1 unit at price 965.400024, total balance 2684.105039
# day 178: buy 1 unit at price 968.150024, total balance 1715.955015
# day 179: buy 1 unit at price 972.919983, total balance 743.035032
# day 185, sell 1 unit at price 930.500000, investment -5.406229 %, total balance 1673.535032,
# day 186, sell 1 unit at price 930.830017, investment -2.096217 %, total balance 2604.365049,
# day 187: buy 1 unit at price 930.390015, total balance 1673.975034
# day 188, sell 1 unit at price 923.650024, investment -3.731303 %, total balance 2597.625058,
# day 189: buy 1 unit at price 927.960022, total balance 1669.665036
# day 190, sell 1 unit at price 929.359985, investment -3.752114 %, total balance 2599.025021,
# day 191, sell 1 unit at price 926.789978, investment -2.675716 %, total balance 3525.814999,
# day 192: buy 1 unit at price 922.900024, total balance 2602.914975
# day 193: buy 1 unit at price 907.239990, total balance 1695.674985
# day 194: buy 1 unit at price 914.390015, total balance 781.284970
# day 200, sell 1 unit at price 906.659973, investment -1.212696 %, total balance 1687.944943,
# day 201: buy 1 unit at price 924.690002, total balance 763.254941
# day 203, sell 1 unit at price 921.280029, investment 0.292840 %, total balance 1684.534970,
# day 204: buy 1 unit at price 915.890015, total balance 768.644955
# day 207, sell 1 unit at price 929.570007, investment 0.082905 %, total balance 1698.214962,
# day 208, sell 1 unit at price 939.330017, investment -0.476781 %, total balance 2637.544979,
# day 209: buy 1 unit at price 937.340027, total balance 1700.204952
# day 212: buy 1 unit at price 935.950012, total balance 764.254940
# day 214, sell 1 unit at price 929.080017, investment -3.762172 %, total balance 1693.334957,
# day 218: buy 1 unit at price 920.289978, total balance 773.044979
# day 222, sell 1 unit at price 932.450012, investment -3.687446 %, total balance 1705.494991,
# day 223, sell 1 unit at price 928.530029, investment -4.562549 %, total balance 2634.025020,
# day 224: buy 1 unit at price 920.969971, total balance 1713.055049
# day 225, sell 1 unit at price 924.859985, investment -0.594378 %, total balance 2637.915034,
# day 226: buy 1 unit at price 944.489990, total balance 1693.425044
# day 227: buy 1 unit at price 949.500000, total balance 743.925044
# day 231, sell 1 unit at price 951.679993, investment 2.556141 %, total balance 1695.605037,
# day 232: buy 1 unit at price 969.960022, total balance 725.645015
# day 234, sell 1 unit at price 977.000000, investment 5.861954 %, total balance 1702.645015,
# day 235: buy 1 unit at price 972.599976, total balance 730.045039
# day 242, sell 1 unit at price 984.450012, investment 8.510430 %, total balance 1714.495051,
# day 245: buy 1 unit at price 970.539978, total balance 743.955073

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
