# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.compat.v1.variable_scope(name):
            tf.compat.v1.disable_eager_execution()
            self.X = tf.compat.v1.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            cell = tf.compat.v1.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.compat.v1.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.compat.v1.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
            feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(input_tensor=feed_action,axis=1,keepdims=True))
            self.cost = tf.reduce_sum(input_tensor=tf.square(self.Y - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
        self.trainable = tf.compat.v1.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<keras.src.layers.rnn.legacy_cells.LSTMCell object at 0x000001F8953B27D0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From C:\Users\joshu\AppData\Local\Temp\ipykernel_16096\2524153651.py:12: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From c:\Users\joshu\miniconda3\Lib\site-packages\keras\src\layers\rnn\legacy_cells.py:1043: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# C:\Users\joshu\AppData\Local\Temp\ipykernel_16096\2524153651.py:10: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_16096\2524153651.py:16: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_action = tf.compat.v1.layers.dense(tensor_action, output_size)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_16096\2524153651.py:17: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_validation = tf.compat.v1.layers.dense(tensor_validation, 1)
# WARNING:tensorflow:<keras.src.layers.rnn.legacy_cells.LSTMCell object at 0x000001F89667B310>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# epoch: 10, total rewards: 1109.255192.3, cost: 0.336463, total money: 1467.635136
# epoch: 20, total rewards: 904.130311.3, cost: 0.068390, total money: 8916.950318
# epoch: 30, total rewards: 1194.075320.3, cost: 0.680754, total money: 2314.095338
# epoch: 40, total rewards: 441.819828.3, cost: 0.214510, total money: 6479.969791
# epoch: 50, total rewards: 1273.714659.3, cost: 0.156006, total money: 10254.444639
# epoch: 60, total rewards: 929.720278.3, cost: 0.415159, total money: 5173.700259
# epoch: 70, total rewards: 727.609981.3, cost: 0.233587, total money: 8786.599971
# epoch: 80, total rewards: 813.260429.3, cost: 0.160857, total money: 7804.790396
# epoch: 90, total rewards: 1816.574773.3, cost: 1.454586, total money: 250.894780
# epoch: 100, total rewards: 1857.370057.3, cost: 0.812777, total money: 2045.580018
# epoch: 110, total rewards: 1458.844909.3, cost: 0.794289, total money: 1762.074827
# epoch: 120, total rewards: 971.085138.3, cost: 0.553214, total money: 4100.555109
# epoch: 130, total rewards: 675.549984.3, cost: 1.757091, total money: 116.809932
# epoch: 140, total rewards: 336.900088.3, cost: 0.323342, total money: 7354.280093
# epoch: 150, total rewards: 673.120299.3, cost: 1.274347, total money: 7690.970274
# epoch: 160, total rewards: -52.934943.3, cost: 0.260688, total money: 5976.385064
# epoch: 170, total rewards: 301.349730.3, cost: 0.159305, total money: 2359.209714
# epoch: 180, total rewards: 1019.259890.3, cost: 0.197317, total money: 5099.409852
# epoch: 190, total rewards: 211.570007.3, cost: 0.286549, total money: 4256.959961
# epoch: 200, total rewards: 57.789613.3, cost: 0.108259, total money: 10057.789613

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 5: buy 1 unit at price 785.309998, total balance 9214.690002
# day 6, sell 1 unit at price 762.559998, investment -2.896945 %, total balance 9977.250000,
# day 7: buy 1 unit at price 754.020020, total balance 9223.229980
# day 11, sell 1 unit at price 771.229980, investment 2.282427 %, total balance 9994.459960,
# day 17: buy 1 unit at price 768.239990, total balance 9226.219970
# day 18, sell 1 unit at price 770.840027, investment 0.338441 %, total balance 9997.059997,
# day 19: buy 1 unit at price 758.039978, total balance 9239.020019
# day 20: buy 1 unit at price 747.919983, total balance 8491.100036
# day 22, sell 1 unit at price 762.520020, investment 0.591003 %, total balance 9253.620056,
# day 23, sell 1 unit at price 759.109985, investment 1.496150 %, total balance 10012.730041,
# day 27: buy 1 unit at price 789.270020, total balance 9223.460021
# day 28, sell 1 unit at price 796.099976, investment 0.865351 %, total balance 10019.559997,
# day 29: buy 1 unit at price 797.070007, total balance 9222.489990
# day 30, sell 1 unit at price 797.849976, investment 0.097855 %, total balance 10020.339966,
# day 33: buy 1 unit at price 796.419983, total balance 9223.919983
# day 34: buy 1 unit at price 794.559998, total balance 8429.359985
# day 35: buy 1 unit at price 791.260010, total balance 7638.099975
# day 36: buy 1 unit at price 789.909973, total balance 6848.190002
# day 37, sell 1 unit at price 791.549988, investment -0.611486 %, total balance 7639.739990,
# day 38, sell 1 unit at price 785.049988, investment -1.196890 %, total balance 8424.789978,
# day 39, sell 1 unit at price 782.789978, investment -1.070449 %, total balance 9207.579956,
# day 40, sell 1 unit at price 771.820007, investment -2.290130 %, total balance 9979.399963,
# day 59: buy 1 unit at price 802.320007, total balance 9177.079956
# day 60, sell 1 unit at price 796.789978, investment -0.689255 %, total balance 9973.869934,
# day 61: buy 1 unit at price 795.695007, total balance 9178.174927
# day 63, sell 1 unit at price 801.489990, investment 0.728292 %, total balance 9979.664917,
# day 71: buy 1 unit at price 818.979980, total balance 9160.684937
# day 73: buy 1 unit at price 828.070007, total balance 8332.614930
# day 74, sell 1 unit at price 831.659973, investment 1.548267 %, total balance 9164.274903,
# day 76, sell 1 unit at price 831.330017, investment 0.393688 %, total balance 9995.604920,
# day 79: buy 1 unit at price 823.210022, total balance 9172.394898
# day 80, sell 1 unit at price 835.239990, investment 1.461349 %, total balance 10007.634888,
# day 85: buy 1 unit at price 835.369995, total balance 9172.264893
# day 86: buy 1 unit at price 838.679993, total balance 8333.584900
# day 88: buy 1 unit at price 845.539978, total balance 7488.044922
# day 92, sell 1 unit at price 852.119995, investment 2.005100 %, total balance 8340.164917,
# day 94, sell 1 unit at price 830.460022, investment -0.980108 %, total balance 9170.624939,
# day 96, sell 1 unit at price 817.580017, investment -3.306758 %, total balance 9988.204956,
# day 97: buy 1 unit at price 814.429993, total balance 9173.774963
# day 98: buy 1 unit at price 819.510010, total balance 8354.264953
# day 100: buy 1 unit at price 831.409973, total balance 7522.854980
# day 102, sell 1 unit at price 829.559998, investment 1.857742 %, total balance 8352.414978,
# day 103, sell 1 unit at price 838.549988, investment 2.323337 %, total balance 9190.964966,
# day 106: buy 1 unit at price 827.880005, total balance 8363.084961
# day 107, sell 1 unit at price 824.669983, investment -0.810670 %, total balance 9187.754944,
# day 108: buy 1 unit at price 824.729980, total balance 8363.024964
# day 110, sell 1 unit at price 824.320007, investment -0.430014 %, total balance 9187.344971,
# day 111, sell 1 unit at price 823.559998, investment -0.141862 %, total balance 10010.904969,
# day 113: buy 1 unit at price 836.820007, total balance 9174.084962
# day 114, sell 1 unit at price 838.210022, investment 0.166107 %, total balance 10012.294984,
# day 125: buy 1 unit at price 931.659973, total balance 9080.635011
# day 128, sell 1 unit at price 932.169983, investment 0.054742 %, total balance 10012.804994,
# day 138: buy 1 unit at price 948.820007, total balance 9063.984987
# day 139: buy 1 unit at price 954.960022, total balance 8109.024965
# day 140, sell 1 unit at price 969.539978, investment 2.183762 %, total balance 9078.564943,
# day 141, sell 1 unit at price 971.469971, investment 1.728863 %, total balance 10050.034914,
# day 142: buy 1 unit at price 975.880005, total balance 9074.154909
# day 143, sell 1 unit at price 964.859985, investment -1.129239 %, total balance 10039.014894,
# day 146: buy 1 unit at price 983.679993, total balance 9055.334901
# day 147: buy 1 unit at price 976.570007, total balance 8078.764894
# day 149, sell 1 unit at price 983.409973, investment -0.027450 %, total balance 9062.174867,
# day 150, sell 1 unit at price 949.830017, investment -2.738154 %, total balance 10012.004884,
# day 153: buy 1 unit at price 950.760010, total balance 9061.244874
# day 154, sell 1 unit at price 942.309998, investment -0.888764 %, total balance 10003.554872,
# day 155: buy 1 unit at price 939.780029, total balance 9063.774843
# day 156, sell 1 unit at price 957.369995, investment 1.871711 %, total balance 10021.144838,
# day 158: buy 1 unit at price 959.450012, total balance 9061.694826
# day 159, sell 1 unit at price 957.090027, investment -0.245973 %, total balance 10018.784853,
# day 167: buy 1 unit at price 911.710022, total balance 9107.074831
# day 168, sell 1 unit at price 906.690002, investment -0.550616 %, total balance 10013.764833,
# day 179: buy 1 unit at price 972.919983, total balance 9040.844850
# day 180: buy 1 unit at price 980.340027, total balance 8060.504823
# day 181: buy 1 unit at price 950.700012, total balance 7109.804811
# day 183, sell 1 unit at price 934.090027, investment -3.991074 %, total balance 8043.894838,
# day 184: buy 1 unit at price 941.530029, total balance 7102.364809
# day 185: buy 1 unit at price 930.500000, total balance 6171.864809
# day 186, sell 1 unit at price 930.830017, investment -5.050290 %, total balance 7102.694826,
# day 189: buy 1 unit at price 927.960022, total balance 6174.734804
# day 190, sell 1 unit at price 929.359985, investment -2.244665 %, total balance 7104.094789,
# day 191, sell 1 unit at price 926.789978, investment -1.565542 %, total balance 8030.884767,
# day 192: buy 1 unit at price 922.900024, total balance 7107.984743
# day 193, sell 1 unit at price 907.239990, investment -2.499732 %, total balance 8015.224733,
# day 194: buy 1 unit at price 914.390015, total balance 7100.834718
# day 195, sell 1 unit at price 922.669983, investment -0.570072 %, total balance 8023.504701,
# day 196: buy 1 unit at price 922.219971, total balance 7101.284730
# day 197, sell 1 unit at price 926.960022, investment 0.439917 %, total balance 8028.244752,
# day 198: buy 1 unit at price 910.979980, total balance 7117.264772
# day 199: buy 1 unit at price 910.669983, total balance 6206.594789
# day 200, sell 1 unit at price 906.659973, investment -0.845377 %, total balance 7113.254762,
# day 201: buy 1 unit at price 924.690002, total balance 6188.564760
# day 203, sell 1 unit at price 921.280029, investment -0.101922 %, total balance 7109.844789,
# day 204, sell 1 unit at price 915.890015, investment 0.538984 %, total balance 8025.734804,
# day 208, sell 1 unit at price 939.330017, investment 3.147137 %, total balance 8965.064821,
# day 209: buy 1 unit at price 937.340027, total balance 8027.724794
# day 210, sell 1 unit at price 928.450012, investment 0.406624 %, total balance 8956.174806,
# day 211, sell 1 unit at price 927.809998, investment -1.016710 %, total balance 9883.984804,
# day 214: buy 1 unit at price 929.080017, total balance 8954.904787
# day 215, sell 1 unit at price 932.070007, investment 0.321823 %, total balance 9886.974794,
# day 218: buy 1 unit at price 920.289978, total balance 8966.684816
# day 219: buy 1 unit at price 915.000000, total balance 8051.684816
# day 220, sell 1 unit at price 921.809998, investment 0.165168 %, total balance 8973.494814,
# day 223, sell 1 unit at price 928.530029, investment 1.478692 %, total balance 9902.024843,
# day 227: buy 1 unit at price 949.500000, total balance 8952.524843
# day 228, sell 1 unit at price 959.109985, investment 1.012110 %, total balance 9911.634828,
# day 229: buy 1 unit at price 953.270020, total balance 8958.364808
# day 231, sell 1 unit at price 951.679993, investment -0.166797 %, total balance 9910.044801,
# day 235: buy 1 unit at price 972.599976, total balance 8937.444825
# day 238, sell 1 unit at price 989.679993, investment 1.756119 %, total balance 9927.124818,
# day 239: buy 1 unit at price 992.000000, total balance 8935.124818
# day 241, sell 1 unit at price 992.809998, investment 0.081653 %, total balance 9927.934816,
# day 242: buy 1 unit at price 984.450012, total balance 8943.484804
# day 244, sell 1 unit at price 968.450012, investment -1.625273 %, total balance 9911.934816,
# day 245: buy 1 unit at price 970.539978, total balance 8941.394838
# day 246, sell 1 unit at price 973.330017, investment 0.287473 %, total balance 9914.724855,
# day 248: buy 1 unit at price 1019.270020, total balance 8895.454835
# day 249, sell 1 unit at price 1017.109985, investment -0.211920 %, total balance 9912.564820,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
