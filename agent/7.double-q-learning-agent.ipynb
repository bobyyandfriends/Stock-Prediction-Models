# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        tf.compat.v1.disable_eager_execution()
        self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
        self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.compat.v1.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.compat.v1.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(input_tensor=tf.square(self.Y - self.logits))
        self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
        self.trainable = tf.compat.v1.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_10396\1045748527.py:9: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_forward = tf.compat.v1.layers.dense(self.X, layer_size, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_10396\1045748527.py:10: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_forward, output_size)
# epoch: 10, total rewards: 149.249878.3, cost: 1.311438, total money: 9132.609863
# epoch: 20, total rewards: 1956.345098.3, cost: 0.819234, total money: 1275.345098
# epoch: 30, total rewards: 964.800229.3, cost: 1.116197, total money: 8931.050229
# epoch: 40, total rewards: 369.590332.3, cost: 0.915287, total money: 8333.680297
# epoch: 50, total rewards: 1174.595335.3, cost: 0.996928, total money: 8146.035337
# epoch: 60, total rewards: 1538.659910.3, cost: 1.061550, total money: 10519.389890
# epoch: 70, total rewards: 534.655149.3, cost: 0.340893, total money: 7585.645139
# epoch: 80, total rewards: 1001.845216.3, cost: 0.527179, total money: 11001.845216
# epoch: 90, total rewards: 534.149843.3, cost: 0.301437, total money: 9517.039858
# epoch: 100, total rewards: 2170.839963.3, cost: 1.969840, total money: 6249.179929
# epoch: 110, total rewards: 1662.565006.3, cost: 0.707750, total money: 11662.565006
# epoch: 120, total rewards: 1677.519837.3, cost: 1.404789, total money: 9685.689819
# epoch: 130, total rewards: 319.790282.3, cost: 1.023117, total money: 5331.280271
# epoch: 140, total rewards: -136.565251.3, cost: 0.325649, total money: 8846.324764
# epoch: 150, total rewards: 115.959779.3, cost: 1.242587, total money: 9098.849794
# epoch: 160, total rewards: 47.600218.3, cost: 0.133471, total money: 9030.960203
# epoch: 170, total rewards: 59.170164.3, cost: 0.013868, total money: 10059.170164
# epoch: 180, total rewards: 174.675049.3, cost: 0.016259, total money: 10174.675049
# epoch: 190, total rewards: 152.454898.3, cost: 0.009921, total money: 10152.454898
# epoch: 200, total rewards: 65.540040.3, cost: 0.064320, total money: 10065.540040

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 762.130005, total balance 9237.869995
# day 2, sell 1 unit at price 762.020020, investment -0.014431 %, total balance 9999.890015,
# day 7: buy 1 unit at price 754.020020, total balance 9245.869995
# day 8, sell 1 unit at price 736.080017, investment -2.379248 %, total balance 9981.950012,
# day 21: buy 1 unit at price 750.500000, total balance 9231.450012
# day 22: buy 1 unit at price 762.520020, total balance 8468.929992
# day 23, sell 1 unit at price 759.109985, investment 1.147233 %, total balance 9228.039977,
# day 26: buy 1 unit at price 789.289978, total balance 8438.749999
# day 27, sell 1 unit at price 789.270020, investment 3.508105 %, total balance 9228.020019,
# day 28: buy 1 unit at price 796.099976, total balance 8431.920043
# day 30, sell 1 unit at price 797.849976, investment 1.084519 %, total balance 9229.770019,
# day 31, sell 1 unit at price 790.799988, investment -0.665744 %, total balance 10020.570007,
# day 32: buy 1 unit at price 794.200012, total balance 9226.369995
# day 33, sell 1 unit at price 796.419983, investment 0.279523 %, total balance 10022.789978,
# day 48: buy 1 unit at price 806.359985, total balance 9216.429993
# day 49: buy 1 unit at price 807.880005, total balance 8408.549988
# day 50, sell 1 unit at price 804.609985, investment -0.217025 %, total balance 9213.159973,
# day 51, sell 1 unit at price 806.070007, investment -0.224043 %, total balance 10019.229980,
# day 57: buy 1 unit at price 832.150024, total balance 9187.079956
# day 58, sell 1 unit at price 823.309998, investment -1.062312 %, total balance 10010.389954,
# day 83: buy 1 unit at price 827.780029, total balance 9182.609925
# day 85, sell 1 unit at price 835.369995, investment 0.916906 %, total balance 10017.979920,
# day 93: buy 1 unit at price 848.400024, total balance 9169.579896
# day 94, sell 1 unit at price 830.460022, investment -2.114569 %, total balance 10000.039918,
# day 95: buy 1 unit at price 829.590027, total balance 9170.449891
# day 96, sell 1 unit at price 817.580017, investment -1.447704 %, total balance 9988.029908,
# day 102: buy 1 unit at price 829.559998, total balance 9158.469910
# day 103, sell 1 unit at price 838.549988, investment 1.083706 %, total balance 9997.019898,
# day 111: buy 1 unit at price 823.559998, total balance 9173.459900
# day 112, sell 1 unit at price 837.169983, investment 1.652580 %, total balance 10010.629883,
# day 113: buy 1 unit at price 836.820007, total balance 9173.809876
# day 114, sell 1 unit at price 838.210022, investment 0.166107 %, total balance 10012.019898,
# day 117: buy 1 unit at price 862.760010, total balance 9149.259888
# day 118, sell 1 unit at price 872.299988, investment 1.105751 %, total balance 10021.559876,
# day 126: buy 1 unit at price 927.130005, total balance 9094.429871
# day 128: buy 1 unit at price 932.169983, total balance 8162.259888
# day 129, sell 1 unit at price 928.780029, investment 0.177971 %, total balance 9091.039917,
# day 130, sell 1 unit at price 930.599976, investment -0.168425 %, total balance 10021.639893,
# day 151: buy 1 unit at price 942.900024, total balance 9078.739869
# day 152: buy 1 unit at price 953.400024, total balance 8125.339845
# day 153, sell 1 unit at price 950.760010, investment 0.833597 %, total balance 9076.099855,
# day 154, sell 1 unit at price 942.309998, investment -1.163208 %, total balance 10018.409853,
# day 163: buy 1 unit at price 940.489990, total balance 9077.919863
# day 164, sell 1 unit at price 917.789978, investment -2.413637 %, total balance 9995.709841,
# day 168: buy 1 unit at price 906.690002, total balance 9089.019839
# day 169, sell 1 unit at price 918.590027, investment 1.312469 %, total balance 10007.609866,
# day 170: buy 1 unit at price 928.799988, total balance 9078.809878
# day 171, sell 1 unit at price 930.090027, investment 0.138893 %, total balance 10008.899905,
# day 173: buy 1 unit at price 947.159973, total balance 9061.739932
# day 174, sell 1 unit at price 955.989990, investment 0.932262 %, total balance 10017.729922,
# day 175: buy 1 unit at price 953.419983, total balance 9064.309939
# day 176, sell 1 unit at price 965.400024, investment 1.256533 %, total balance 10029.709963,
# day 178: buy 1 unit at price 968.150024, total balance 9061.559939
# day 179, sell 1 unit at price 972.919983, investment 0.492688 %, total balance 10034.479922,
# day 182: buy 1 unit at price 947.799988, total balance 9086.679934
# day 183, sell 1 unit at price 934.090027, investment -1.446504 %, total balance 10020.769961,
# day 185: buy 1 unit at price 930.500000, total balance 9090.269961
# day 186: buy 1 unit at price 930.830017, total balance 8159.439944
# day 187, sell 1 unit at price 930.390015, investment -0.011820 %, total balance 9089.829959,
# day 189: buy 1 unit at price 927.960022, total balance 8161.869937
# day 190, sell 1 unit at price 929.359985, investment -0.157927 %, total balance 9091.229922,
# day 191, sell 1 unit at price 926.789978, investment -0.126088 %, total balance 10018.019900,
# day 193: buy 1 unit at price 907.239990, total balance 9110.779910
# day 194, sell 1 unit at price 914.390015, investment 0.788107 %, total balance 10025.169925,
# day 202: buy 1 unit at price 927.000000, total balance 9098.169925
# day 204, sell 1 unit at price 915.890015, investment -1.198488 %, total balance 10014.059940,
# day 207: buy 1 unit at price 929.570007, total balance 9084.489933
# day 208, sell 1 unit at price 939.330017, investment 1.049949 %, total balance 10023.819950,
# day 228: buy 1 unit at price 959.109985, total balance 9064.709965
# day 229, sell 1 unit at price 953.270020, investment -0.608894 %, total balance 10017.979985,
# day 230: buy 1 unit at price 957.789978, total balance 9060.190007
# day 231: buy 1 unit at price 951.679993, total balance 8108.510014
# day 232, sell 1 unit at price 969.960022, investment 1.270638 %, total balance 9078.470036,
# day 233, sell 1 unit at price 978.890015, investment 2.859157 %, total balance 10057.360051,
# day 235: buy 1 unit at price 972.599976, total balance 9084.760075
# day 236, sell 1 unit at price 989.250000, investment 1.711909 %, total balance 10074.010075,
# day 242: buy 1 unit at price 984.450012, total balance 9089.560063
# day 243, sell 1 unit at price 988.200012, investment 0.380923 %, total balance 10077.760075,
# day 247: buy 1 unit at price 972.559998, total balance 9105.200077
# day 248, sell 1 unit at price 1019.270020, investment 4.802791 %, total balance 10124.470097,
# day 250: buy 1 unit at price 1016.640015, total balance 9107.830082

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
