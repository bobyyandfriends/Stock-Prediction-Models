# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# matplotlib==3.7.2
# numpy==1.24.3
# pandas==2.0.3
# seaborn==0.12.2

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 15.786600
# iter 20. reward: 21.765902
# iter 30. reward: 21.087500
# iter 40. reward: 24.044750
# iter 50. reward: 23.352051
# iter 60. reward: 24.778702
# iter 70. reward: 22.318803
# iter 80. reward: 24.216899
# iter 90. reward: 27.442899
# iter 100. reward: 28.361001
# iter 110. reward: 28.093100
# iter 120. reward: 27.533701
# iter 130. reward: 29.872650
# iter 140. reward: 30.198498
# iter 150. reward: 30.322299
# iter 160. reward: 30.601998
# iter 170. reward: 33.370098
# iter 180. reward: 35.471801
# iter 190. reward: 34.828401
# iter 200. reward: 35.581699
# iter 210. reward: 33.301099
# iter 220. reward: 34.692150
# iter 230. reward: 33.917447
# iter 240. reward: 34.335298
# iter 250. reward: 34.173298
# iter 260. reward: 35.110400
# iter 270. reward: 35.513800
# iter 280. reward: 34.685699
# iter 290. reward: 36.550399
# iter 300. reward: 32.887849
# iter 310. reward: 36.298250
# iter 320. reward: 35.218748
# iter 330. reward: 36.213349
# iter 340. reward: 37.032048
# iter 350. reward: 36.722050
# iter 360. reward: 34.638249
# iter 370. reward: 36.791047
# iter 380. reward: 36.584747
# iter 390. reward: 34.140849
# iter 400. reward: 36.144047
# iter 410. reward: 36.517249
# iter 420. reward: 36.556349
# iter 430. reward: 38.054349
# iter 440. reward: 27.741948
# iter 450. reward: 38.867849
# iter 460. reward: 39.395149
# iter 470. reward: 39.638049
# iter 480. reward: 38.811449
# iter 490. reward: 38.735948
# iter 500. reward: 39.235899
# time taken to train: 125.65517449378967 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1: buy 1 unit at price 762.130005, total balance 8469.169983
# day 2: buy 1 unit at price 762.020020, total balance 7707.149963
# day 5, sell 1 unit at price 785.309998, investment 2.160789 %, total balance 8492.459961,
# day 6: buy 1 unit at price 762.559998, total balance 7729.899963
# day 7: buy 1 unit at price 754.020020, total balance 6975.879943
# day 8: buy 1 unit at price 736.080017, total balance 6239.799926
# day 9: buy 1 unit at price 758.489990, total balance 5481.309936
# day 13: buy 1 unit at price 769.200012, total balance 4712.109924
# day 14: buy 1 unit at price 768.270020, total balance 3943.839904
# day 15: buy 1 unit at price 760.989990, total balance 3182.849914
# day 16: buy 1 unit at price 761.679993, total balance 2421.169921
# day 17: buy 1 unit at price 768.239990, total balance 1652.929931
# day 18, sell 1 unit at price 770.840027, investment 1.142853 %, total balance 2423.769958,
# day 21: buy 1 unit at price 750.500000, total balance 1673.269958
# day 22: buy 1 unit at price 762.520020, total balance 910.749938
# day 25: buy 1 unit at price 776.419983, total balance 134.329955
# day 26, sell 1 unit at price 789.289978, investment 3.578641 %, total balance 923.619933,
# day 27: buy 1 unit at price 789.270020, total balance 134.349913
# day 31, sell 1 unit at price 790.799988, investment 3.703314 %, total balance 925.149901,
# day 32, sell 1 unit at price 794.200012, investment 5.328770 %, total balance 1719.349913,
# day 33, sell 1 unit at price 796.419983, investment 8.197474 %, total balance 2515.769896,
# day 35: buy 1 unit at price 791.260010, total balance 1724.509886
# day 36: buy 1 unit at price 789.909973, total balance 934.599913
# day 37, sell 1 unit at price 791.549988, investment 4.358660 %, total balance 1726.149901,
# day 39: buy 1 unit at price 782.789978, total balance 943.359923
# day 40: buy 1 unit at price 771.820007, total balance 171.539916
# day 44, sell 1 unit at price 806.150024, investment 4.803694 %, total balance 977.689940,
# day 45, sell 1 unit at price 806.650024, investment 4.995640 %, total balance 1784.339964,
# day 46, sell 1 unit at price 804.789978, investment 5.755659 %, total balance 2589.129942,
# day 47: buy 1 unit at price 807.909973, total balance 1781.219969
# day 48: buy 1 unit at price 806.359985, total balance 974.859984
# day 50: buy 1 unit at price 804.609985, total balance 170.249999
# day 55, sell 1 unit at price 823.869995, investment 8.164846 %, total balance 994.119994,
# day 56, sell 1 unit at price 835.669983, investment 8.777204 %, total balance 1829.789977,
# day 58, sell 1 unit at price 823.309998, investment 9.701532 %, total balance 2653.099975,
# day 59: buy 1 unit at price 802.320007, total balance 1850.779968
# day 60: buy 1 unit at price 796.789978, total balance 1053.989990
# day 64, sell 1 unit at price 801.340027, investment 5.091015 %, total balance 1855.330017,
# day 65, sell 1 unit at price 806.969971, investment 3.934725 %, total balance 2662.299988,
# day 66: buy 1 unit at price 808.380005, total balance 1853.919983
# day 67: buy 1 unit at price 809.559998, total balance 1044.359985
# day 68: buy 1 unit at price 813.669983, total balance 230.690002
# day 70, sell 1 unit at price 820.450012, investment 3.950485 %, total balance 1051.140014,
# day 72, sell 1 unit at price 824.159973, investment 4.157921 %, total balance 1875.299987,
# day 76: buy 1 unit at price 831.330017, total balance 1043.969970
# day 77, sell 1 unit at price 828.640015, investment 4.903096 %, total balance 1872.609985,
# day 78: buy 1 unit at price 829.280029, total balance 1043.329956
# day 79: buy 1 unit at price 823.210022, total balance 220.119934
# day 84, sell 1 unit at price 831.909973, investment 6.274990 %, total balance 1052.029907,
# day 85, sell 1 unit at price 835.369995, investment 8.233783 %, total balance 1887.399902,
# day 86, sell 1 unit at price 838.679993, investment 3.808595 %, total balance 2726.079895,
# day 87: buy 1 unit at price 843.250000, total balance 1882.829895
# day 88, sell 1 unit at price 845.539978, investment 4.858871 %, total balance 2728.369873,
# day 89, sell 1 unit at price 845.619995, investment 5.096881 %, total balance 3573.989868,
# day 90, sell 1 unit at price 847.200012, investment 5.593779 %, total balance 4421.189880,
# day 91, sell 1 unit at price 848.780029, investment 6.524938 %, total balance 5269.969909,
# day 92, sell 1 unit at price 852.119995, investment 5.410820 %, total balance 6122.089904,
# day 94, sell 1 unit at price 830.460022, investment 2.581652 %, total balance 6952.549926,
# day 95: buy 1 unit at price 829.590027, total balance 6122.959899
# day 96: buy 1 unit at price 817.580017, total balance 5305.379882
# day 98: buy 1 unit at price 819.510010, total balance 4485.869872
# day 99: buy 1 unit at price 820.919983, total balance 3664.949889
# day 101, sell 1 unit at price 831.500000, investment 2.191308 %, total balance 4496.449889,
# day 102: buy 1 unit at price 829.559998, total balance 3666.889891
# day 103, sell 1 unit at price 838.549988, investment 0.868484 %, total balance 4505.439879,
# day 104: buy 1 unit at price 834.570007, total balance 3670.869872
# day 106: buy 1 unit at price 827.880005, total balance 2842.989867
# day 107: buy 1 unit at price 824.669983, total balance 2018.319884
# day 109: buy 1 unit at price 823.349976, total balance 1194.969908
# day 110: buy 1 unit at price 824.320007, total balance 370.649901
# day 114, sell 1 unit at price 838.210022, investment 1.076837 %, total balance 1208.859923,
# day 116: buy 1 unit at price 843.190002, total balance 365.669921
# day 123, sell 1 unit at price 916.440002, investment 11.325176 %, total balance 1282.109923,
# day 124: buy 1 unit at price 927.039978, total balance 355.069945
# day 126, sell 1 unit at price 927.130005, investment 9.947229 %, total balance 1282.199950,
# day 129, sell 1 unit at price 928.780029, investment 11.956508 %, total balance 2210.979979,
# day 131, sell 1 unit at price 932.219971, investment 14.021864 %, total balance 3143.199950,
# day 132, sell 1 unit at price 937.080017, investment 14.346378 %, total balance 4080.279967,
# day 133, sell 1 unit at price 943.000000, investment 14.871123 %, total balance 5023.279967,
# day 135, sell 1 unit at price 930.239990, investment 12.136553 %, total balance 5953.519957,
# day 136: buy 1 unit at price 934.010010, total balance 5019.509947
# day 138, sell 1 unit at price 948.820007, investment 13.689684 %, total balance 5968.329954,
# day 139: buy 1 unit at price 954.960022, total balance 5013.369932
# day 140, sell 1 unit at price 969.539978, investment 17.111172 %, total balance 5982.909910,
# day 141, sell 1 unit at price 971.469971, investment 17.801059 %, total balance 6954.379881,
# day 142, sell 1 unit at price 975.880005, investment 18.525540 %, total balance 7930.259886,
# day 143: buy 1 unit at price 964.859985, total balance 6965.399901
# day 144, sell 1 unit at price 966.950012, investment 17.302747 %, total balance 7932.349913,
# day 145, sell 1 unit at price 975.599976, investment 15.703456 %, total balance 8907.949889,
# day 147, sell 1 unit at price 976.570007, investment 5.342815 %, total balance 9884.519896,
# day 149, sell 1 unit at price 983.409973, investment 5.289019 %, total balance 10867.929869,
# day 150: buy 1 unit at price 949.830017, total balance 9918.099852
# day 151: buy 1 unit at price 942.900024, total balance 8975.199828
# day 153, sell 1 unit at price 950.760010, investment -0.439810 %, total balance 9925.959838,
# day 155: buy 1 unit at price 939.780029, total balance 8986.179809
# day 156, sell 1 unit at price 957.369995, investment -0.776277 %, total balance 9943.549804,
# day 158: buy 1 unit at price 959.450012, total balance 8984.099792
# day 159, sell 1 unit at price 957.090027, investment 0.764348 %, total balance 9941.189819,
# day 160, sell 1 unit at price 965.590027, investment 2.406406 %, total balance 10906.779846,
# day 161, sell 1 unit at price 952.270020, investment 1.329033 %, total balance 11859.049866,
# day 162: buy 1 unit at price 927.330017, total balance 10931.719849
# day 163, sell 1 unit at price 940.489990, investment -1.976134 %, total balance 11872.209839,
# day 164: buy 1 unit at price 917.789978, total balance 10954.419861
# day 166: buy 1 unit at price 898.700012, total balance 10055.719849
# day 167: buy 1 unit at price 911.710022, total balance 9144.009827
# day 169: buy 1 unit at price 918.590027, total balance 8225.419800
# day 170: buy 1 unit at price 928.799988, total balance 7296.619812
# day 171: buy 1 unit at price 930.090027, total balance 6366.529785
# day 172, sell 1 unit at price 943.830017, investment 1.779302 %, total balance 7310.359802,
# day 174, sell 1 unit at price 955.989990, investment 4.162174 %, total balance 8266.349792,
# day 175, sell 1 unit at price 953.419983, investment 6.088792 %, total balance 9219.769775,
# day 177, sell 1 unit at price 970.890015, investment 6.491098 %, total balance 10190.659790,
# day 178: buy 1 unit at price 968.150024, total balance 9222.509766
# day 179, sell 1 unit at price 972.919983, investment 5.914494 %, total balance 10195.429749,
# day 181: buy 1 unit at price 950.700012, total balance 9244.729737
# day 182: buy 1 unit at price 947.799988, total balance 8296.929749
# day 183: buy 1 unit at price 934.090027, total balance 7362.839722
# day 184, sell 1 unit at price 941.530029, investment 1.370590 %, total balance 8304.369751,
# day 186, sell 1 unit at price 930.830017, investment 0.079561 %, total balance 9235.199768,
# day 188, sell 1 unit at price 923.650024, investment -4.596395 %, total balance 10158.849792,
# day 189: buy 1 unit at price 927.960022, total balance 9230.889770
# day 190: buy 1 unit at price 929.359985, total balance 8301.529785
# day 191, sell 1 unit at price 926.789978, investment -2.514993 %, total balance 9228.319763,
# day 192: buy 1 unit at price 922.900024, total balance 8305.419739
# day 193: buy 1 unit at price 907.239990, total balance 7398.179749
# day 194: buy 1 unit at price 914.390015, total balance 6483.789734
# day 195: buy 1 unit at price 922.669983, total balance 5561.119751
# day 198: buy 1 unit at price 910.979980, total balance 4650.139771
# day 200: buy 1 unit at price 906.659973, total balance 3743.479798
# day 201: buy 1 unit at price 924.690002, total balance 2818.789796
# day 202: buy 1 unit at price 927.000000, total balance 1891.789796
# day 205: buy 1 unit at price 913.809998, total balance 977.979798
# day 206, sell 1 unit at price 921.289978, investment -2.797005 %, total balance 1899.269776,
# day 208, sell 1 unit at price 939.330017, investment 0.560973 %, total balance 2838.599793,
# day 210: buy 1 unit at price 928.450012, total balance 1910.149781
# day 212: buy 1 unit at price 935.950012, total balance 974.199769
# day 213: buy 1 unit at price 926.500000, total balance 47.699769
# day 217, sell 1 unit at price 925.109985, investment -0.307129 %, total balance 972.809754,
# day 218: buy 1 unit at price 920.289978, total balance 52.519776
# day 223, sell 1 unit at price 928.530029, investment -0.089304 %, total balance 981.049805,
# day 224: buy 1 unit at price 920.969971, total balance 60.079834
# day 229, sell 1 unit at price 953.270020, investment 3.290714 %, total balance 1013.349854,
# day 230: buy 1 unit at price 957.789978, total balance 55.559876
# day 234, sell 1 unit at price 977.000000, investment 7.689257 %, total balance 1032.559876,
# day 235, sell 1 unit at price 972.599976, investment 6.365988 %, total balance 2005.159852,
# day 236, sell 1 unit at price 989.250000, investment 7.216016 %, total balance 2994.409852,
# day 237, sell 1 unit at price 987.830017, investment 8.435974 %, total balance 3982.239869,
# day 238, sell 1 unit at price 989.679993, investment 9.156687 %, total balance 4971.919862,
# day 240, sell 1 unit at price 992.179993, investment 7.298661 %, total balance 5964.099855,
# day 241, sell 1 unit at price 992.809998, investment 7.099245 %, total balance 6956.909853,
# day 242, sell 1 unit at price 984.450012, investment 7.730274 %, total balance 7941.359865,
# day 243, sell 1 unit at price 988.200012, investment 6.435457 %, total balance 8929.559877,
# day 244, sell 1 unit at price 968.450012, investment 3.472408 %, total balance 9898.009889,
# day 247, sell 1 unit at price 972.559998, investment 4.971398 %, total balance 10870.569887,
# day 248, sell 1 unit at price 1019.270020, investment 10.755310 %, total balance 11889.839907,
# day 249, sell 1 unit at price 1017.109985, investment 10.438996 %, total balance 12906.949892,
# day 250, sell 1 unit at price 1016.640015, investment 6.144357 %, total balance 13923.589907,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
