# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.compat.v1.variable_scope(name):
            tf.compat.v1.disable_eager_execution()
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.compat.v1.variable_scope(name):
            tf.compat.v1.disable_eager_execution()
            self.X = tf.compat.v1.placeholder(tf.float32, (None, input_size))
            self.Y = tf.compat.v1.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.compat.v1.placeholder(tf.float32, (None, 1))
            feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.compat.v1.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(input_tensor=tf.square(self.REWARD - self.logits))
            self.optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.compat.v1.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(ys=self.critic.logits, xs=self.critic.Y)
        self.actor_critic_grad = tf.compat.v1.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(ys=self.actor.logits, xs=weights_actor, grad_ys=-self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.compat.v1.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.compat.v1.InteractiveSession()
        self.sess.run(tf.compat.v1.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                state = next_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:9: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_actor = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:10: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_actor, output_size)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:19: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(self.X, size_layer, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:20: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:21: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   feed_critic = tf.compat.v1.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
# C:\Users\joshu\AppData\Local\Temp\ipykernel_4548\817982328.py:22: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   self.logits = tf.compat.v1.layers.dense(feed_critic, 1)
# epoch: 10, total rewards: 1660.170106.3, cost: 0.121613, total money: 10691.720094
# epoch: 20, total rewards: 1458.459901.3, cost: 43.049679, total money: 7515.869874
# epoch: 30, total rewards: 1164.574646.3, cost: 20293.482422, total money: 9175.374633
# epoch: 40, total rewards: 125.149776.3, cost: 620435520.000000, total money: 7141.139765
# epoch: 50, total rewards: 448.609860.3, cost: 3284312.000000, total money: 10448.609860
# epoch: 60, total rewards: 850.270206.3, cost: 64312848.000000, total money: 3929.690189
# epoch: 70, total rewards: 414.544919.3, cost: 663118656.000000, total money: 2503.114926
# epoch: 80, total rewards: 753.690069.3, cost: 18688442368.000000, total money: 5862.370061
# epoch: 90, total rewards: 2239.344850.3, cost: 33791592448.000000, total money: 7396.674867
# epoch: 100, total rewards: 727.959781.3, cost: 305894129664.000000, total money: 3815.179751
# epoch: 110, total rewards: 511.310299.3, cost: 1557805268992.000000, total money: 9494.200314
# epoch: 120, total rewards: 292.440185.3, cost: 32525500022784.000000, total money: 4344.240172
# epoch: 130, total rewards: 526.495117.3, cost: 42103753146368.000000, total money: 10526.495117
# epoch: 140, total rewards: 1243.150084.3, cost: 59616184500224.000000, total money: 1826.480101
# epoch: 150, total rewards: 382.779848.3, cost: 37728632700928.000000, total money: 10382.779848
# epoch: 160, total rewards: 446.210082.3, cost: 2431052152832000.000000, total money: 2873.300048
# epoch: 170, total rewards: -51.154967.3, cost: 5235680024199168.000000, total money: 9948.845033
# epoch: 180, total rewards: 801.719850.3, cost: 1293986002108416.000000, total money: 7890.169862
# epoch: 190, total rewards: 968.750065.3, cost: 9330840072880128.000000, total money: 8976.920047
# epoch: 200, total rewards: 791.125060.3, cost: 7734625140998144.000000, total money: 1318.305115

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 4: buy 1 unit at price 790.510010, total balance 9209.489990
# day 5, sell 1 unit at price 785.309998, investment -0.657805 %, total balance 9994.799988,
# day 8: buy 1 unit at price 736.080017, total balance 9258.719971
# day 11: buy 1 unit at price 771.229980, total balance 8487.489991
# day 15: buy 1 unit at price 760.989990, total balance 7726.500001
# day 18, sell 1 unit at price 770.840027, investment 4.722314 %, total balance 8497.340028,
# day 19: buy 1 unit at price 758.039978, total balance 7739.300050
# day 21: buy 1 unit at price 750.500000, total balance 6988.800050
# day 22: buy 1 unit at price 762.520020, total balance 6226.280030
# day 23: buy 1 unit at price 759.109985, total balance 5467.170045
# day 25, sell 1 unit at price 776.419983, investment 0.672951 %, total balance 6243.590028,
# day 26, sell 1 unit at price 789.289978, investment 3.718838 %, total balance 7032.880006,
# day 27: buy 1 unit at price 789.270020, total balance 6243.609986
# day 31: buy 1 unit at price 790.799988, total balance 5452.809998
# day 32: buy 1 unit at price 794.200012, total balance 4658.609986
# day 35, sell 1 unit at price 791.260010, investment 4.382359 %, total balance 5449.869996,
# day 36: buy 1 unit at price 789.909973, total balance 4659.960023
# day 37: buy 1 unit at price 791.549988, total balance 3868.410035
# day 38: buy 1 unit at price 785.049988, total balance 3083.360047
# day 41, sell 1 unit at price 786.140015, investment 4.748836 %, total balance 3869.500062,
# day 42: buy 1 unit at price 786.900024, total balance 3082.600038
# day 43: buy 1 unit at price 794.020020, total balance 2288.580018
# day 44, sell 1 unit at price 806.150024, investment 5.721818 %, total balance 3094.730042,
# day 45: buy 1 unit at price 806.650024, total balance 2288.080018
# day 46, sell 1 unit at price 804.789978, investment 6.017572 %, total balance 3092.869996,
# day 47, sell 1 unit at price 807.909973, investment 2.361670 %, total balance 3900.779969,
# day 49: buy 1 unit at price 807.880005, total balance 3092.899964
# day 50: buy 1 unit at price 804.609985, total balance 2288.289979
# day 52, sell 1 unit at price 802.174988, investment 1.438417 %, total balance 3090.464967,
# day 59, sell 1 unit at price 802.320007, investment 1.022412 %, total balance 3892.784974,
# day 60: buy 1 unit at price 796.789978, total balance 3095.994996
# day 62, sell 1 unit at price 798.530029, investment 1.091271 %, total balance 3894.525025,
# day 63: buy 1 unit at price 801.489990, total balance 3093.035035
# day 64, sell 1 unit at price 801.340027, investment 1.236819 %, total balance 3894.375062,
# day 65, sell 1 unit at price 806.969971, investment 2.792177 %, total balance 4701.345033,
# day 66: buy 1 unit at price 808.380005, total balance 3892.965028
# day 71: buy 1 unit at price 818.979980, total balance 3073.985048
# day 72: buy 1 unit at price 824.159973, total balance 2249.825075
# day 74: buy 1 unit at price 831.659973, total balance 1418.165102
# day 75, sell 1 unit at price 830.760010, investment 5.573769 %, total balance 2248.925112,
# day 78: buy 1 unit at price 829.280029, total balance 1419.645083
# day 79: buy 1 unit at price 823.210022, total balance 596.435061
# day 87, sell 1 unit at price 843.250000, investment 6.200093 %, total balance 1439.685061,
# day 89: buy 1 unit at price 845.619995, total balance 594.065066
# day 93, sell 1 unit at price 848.400024, investment 5.175727 %, total balance 1442.465090,
# day 94: buy 1 unit at price 830.460022, total balance 612.005068
# day 108, sell 1 unit at price 824.729980, investment 2.085703 %, total balance 1436.735048,
# day 111: buy 1 unit at price 823.559998, total balance 613.175050
# day 115, sell 1 unit at price 841.650024, investment 4.603477 %, total balance 1454.825074,
# day 116: buy 1 unit at price 843.190002, total balance 611.635072
# day 120, sell 1 unit at price 874.250000, investment 9.721511 %, total balance 1485.885072,
# day 122: buy 1 unit at price 912.570007, total balance 573.315065
# day 125, sell 1 unit at price 931.659973, investment 16.240999 %, total balance 1504.975038,
# day 128, sell 1 unit at price 932.169983, investment 15.313340 %, total balance 2437.145021,
# day 130, sell 1 unit at price 930.599976, investment 13.629148 %, total balance 3367.744997,
# day 131, sell 1 unit at price 932.219971, investment 13.111532 %, total balance 4299.964968,
# day 133, sell 1 unit at price 943.000000, investment 13.387686 %, total balance 5242.964968,
# day 134: buy 1 unit at price 919.619995, total balance 4323.344973
# day 135: buy 1 unit at price 930.239990, total balance 3393.104983
# day 138, sell 1 unit at price 948.820007, investment 14.414911 %, total balance 4341.924990,
# day 139: buy 1 unit at price 954.960022, total balance 3386.964968
# day 143: buy 1 unit at price 964.859985, total balance 2422.104983
# day 144: buy 1 unit at price 966.950012, total balance 1455.154971
# day 146, sell 1 unit at price 983.679993, investment 19.493199 %, total balance 2438.834964,
# day 149: buy 1 unit at price 983.409973, total balance 1455.424991
# day 150, sell 1 unit at price 949.830017, investment 12.323505 %, total balance 2405.255008,
# day 153: buy 1 unit at price 950.760010, total balance 1454.494998
# day 154: buy 1 unit at price 942.309998, total balance 512.185000
# day 156, sell 1 unit at price 957.369995, investment 15.281888 %, total balance 1469.554995,
# day 157, sell 1 unit at price 950.630005, investment 15.429356 %, total balance 2420.185000,
# day 158: buy 1 unit at price 959.450012, total balance 1460.734988
# day 159, sell 1 unit at price 957.090027, investment 13.508228 %, total balance 2417.825015,
# day 162: buy 1 unit at price 927.330017, total balance 1490.494998
# day 164: buy 1 unit at price 917.789978, total balance 572.705020
# day 170, sell 1 unit at price 928.799988, investment 1.778492 %, total balance 1501.505008,
# day 171: buy 1 unit at price 930.090027, total balance 571.414981
# day 174, sell 1 unit at price 955.989990, investment 3.954894 %, total balance 1527.404971,
# day 175, sell 1 unit at price 953.419983, investment 2.491829 %, total balance 2480.824954,
# day 177: buy 1 unit at price 970.890015, total balance 1509.934939
# day 178, sell 1 unit at price 968.150024, investment 1.381210 %, total balance 2478.084963,
# day 179, sell 1 unit at price 972.919983, investment 0.835354 %, total balance 3451.004946,
# day 180, sell 1 unit at price 980.340027, investment 1.384768 %, total balance 4431.344973,
# day 181: buy 1 unit at price 950.700012, total balance 3480.644961
# day 182, sell 1 unit at price 947.799988, investment -3.621072 %, total balance 4428.444949,
# day 183, sell 1 unit at price 934.090027, investment -1.753332 %, total balance 5362.534976,
# day 184, sell 1 unit at price 941.530029, investment -0.082772 %, total balance 6304.065005,
# day 186, sell 1 unit at price 930.830017, investment -2.982958 %, total balance 7234.895022,
# day 188, sell 1 unit at price 923.650024, investment -0.396837 %, total balance 8158.545046,
# day 190: buy 1 unit at price 929.359985, total balance 7229.185061
# day 191, sell 1 unit at price 926.789978, investment 0.980617 %, total balance 8155.975039,
# day 192: buy 1 unit at price 922.900024, total balance 7233.075015
# day 195: buy 1 unit at price 922.669983, total balance 6310.405032
# day 197: buy 1 unit at price 926.960022, total balance 5383.445010
# day 198: buy 1 unit at price 910.979980, total balance 4472.465030
# day 200: buy 1 unit at price 906.659973, total balance 3565.805057
# day 201: buy 1 unit at price 924.690002, total balance 2641.115055
# day 202: buy 1 unit at price 927.000000, total balance 1714.115055
# day 207: buy 1 unit at price 929.570007, total balance 784.545048
# day 209, sell 1 unit at price 937.340027, investment 0.779494 %, total balance 1721.885075,
# day 210, sell 1 unit at price 928.450012, investment -4.371247 %, total balance 2650.335087,
# day 212: buy 1 unit at price 935.950012, total balance 1714.385075
# day 214, sell 1 unit at price 929.080017, investment -2.274113 %, total balance 2643.465092,
# day 217, sell 1 unit at price 925.109985, investment -0.457304 %, total balance 3568.575077,
# day 218: buy 1 unit at price 920.289978, total balance 2648.285099
# day 219: buy 1 unit at price 915.000000, total balance 1733.285099
# day 220, sell 1 unit at price 921.809998, investment -0.118109 %, total balance 2655.095097,
# day 222: buy 1 unit at price 932.450012, total balance 1722.645085
# day 223, sell 1 unit at price 928.530029, investment 0.635118 %, total balance 2651.175114,
# day 224: buy 1 unit at price 920.969971, total balance 1730.205143
# day 228, sell 1 unit at price 959.109985, investment 3.468322 %, total balance 2689.315128,
# day 229, sell 1 unit at price 953.270020, investment 4.642258 %, total balance 3642.585148,
# day 234, sell 1 unit at price 977.000000, investment 7.758148 %, total balance 4619.585148,
# day 237, sell 1 unit at price 987.830017, investment 6.828236 %, total balance 5607.415165,
# day 239, sell 1 unit at price 992.000000, investment 7.011866 %, total balance 6599.415165,
# day 240: buy 1 unit at price 992.179993, total balance 5607.235172
# day 250, sell 1 unit at price 1016.640015, investment 9.366697 %, total balance 6623.875187,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
