# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
import pkg_resources
import types


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# matplotlib==3.7.2
# numpy==1.24.3
# pandas==2.0.3
# seaborn==0.12.2

# %%
def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[0 : t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

# %% [markdown]
# TSLA Time Period: **Mar 23, 2018 - Mar 23, 2019**

# %%
df = pd.read_csv('../dataset/TSLA.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-03-23  311.250000  311.250000  300.450012  301.540009  301.540009
# 1  2018-03-26  307.339996  307.589996  291.359985  304.179993  304.179993
# 2  2018-03-27  304.000000  304.269989  277.179993  279.179993  279.179993
# 3  2018-03-28  264.579987  268.679993  252.100006  257.779999  257.779999
# 4  2018-03-29  256.489990  270.959991  248.210007  266.130005  266.130005
#
#      Volume
# 0   6654900
# 1   8375200
# 2  13872000
# 3  21001400
# 4  15170700

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
l = len(close) - 1

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, money, max_buy, max_sell):
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = get_state(close, 0, window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = get_state(close, 0, window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, l, skip):
            action, buy = self.act(state)
            next_state = get_state(close, t + 1, window_size + 1)
            if action == 1 and initial_money >= close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.show()

# %%
model = Model(window_size, 500, 3)
agent = Agent(model, 10000, 5, 5)
agent.fit(500, 10)
# Out:
# iter 10. reward: 39.866805
# iter 20. reward: 40.580197
# iter 30. reward: 57.620699
# iter 40. reward: 70.379599
# iter 50. reward: 69.224396
# iter 60. reward: 69.535398
# iter 70. reward: 83.756599
# iter 80. reward: 85.906097
# iter 90. reward: 74.179094
# iter 100. reward: 81.030894
# iter 110. reward: 85.734597
# iter 120. reward: 86.297796
# iter 130. reward: 84.885694
# iter 140. reward: 78.140795
# iter 150. reward: 80.496196
# iter 160. reward: 88.729094
# iter 170. reward: 85.812896
# iter 180. reward: 85.320796
# iter 190. reward: 85.781297
# iter 200. reward: 85.822397
# iter 210. reward: 87.662199
# iter 220. reward: 84.687001
# iter 230. reward: 84.367498
# iter 240. reward: 87.622401
# iter 250. reward: 89.033395
# iter 260. reward: 87.978097
# iter 270. reward: 88.349895
# iter 280. reward: 90.824294
# iter 290. reward: 83.968895
# iter 300. reward: 87.434193
# iter 310. reward: 99.871295
# iter 320. reward: 93.370194
# iter 330. reward: 101.521697
# iter 340. reward: 98.204999
# iter 350. reward: 97.423696
# iter 360. reward: 101.850397
# iter 370. reward: 95.163000
# iter 380. reward: 102.234394
# iter 390. reward: 102.810695
# iter 400. reward: 102.488198
# iter 410. reward: 104.929495
# iter 420. reward: 100.200791
# iter 430. reward: 103.600292
# iter 440. reward: 104.585992
# iter 450. reward: 107.887891
# iter 460. reward: 109.656390
# iter 470. reward: 101.507095
# iter 480. reward: 102.125393
# iter 490. reward: 100.914093
# iter 500. reward: 106.775093
# time taken to train: 125.90321135520935 seconds

# %%
agent.buy()
# Out:
# day 2: buy 5 units at price 1395.899965, total balance 8604.100035
# day 3: buy 5 units at price 1288.899995, total balance 7315.200040
# day 4: buy 5 units at price 1330.650025, total balance 5984.550015
# day 5: buy 5 units at price 1262.399980, total balance 4722.150035
# day 6: buy 1 units at price 267.529999, total balance 4454.620036
# day 7: buy 1 units at price 286.940002, total balance 4167.680034
# day 8, sell 5 units at price 1528.600005, investment 9.506415 %, total balance 5696.280039,
# day 10, sell 5 units at price 1448.300020, investment 12.367137 %, total balance 7144.580059,
# day 11, sell 5 units at price 1523.500060, investment 14.492919 %, total balance 8668.080119,
# day 12, sell 5 units at price 1504.649965, investment 19.189638 %, total balance 10172.730084,
# day 13: buy 1 units at price 294.079987, total balance 9878.650097
# day 16: buy 1 units at price 287.690002, total balance 9590.960095
# day 18, sell 4 units at price 1200.319948, investment 348.667421 %, total balance 10791.280043,
# day 19: buy 5 units at price 1451.199950, total balance 9340.080093
# day 20: buy 1 units at price 283.369995, total balance 9056.710098
# day 21: buy 1 units at price 283.459991, total balance 8773.250107
# day 23: buy 5 units at price 1427.400055, total balance 7345.850052
# day 25, sell 5 units at price 1469.499970, investment 412.127957 %, total balance 8815.350022,
# day 26: buy 5 units at price 1499.600065, total balance 7315.749957
# day 27, sell 5 units at price 1505.749970, investment 412.020551 %, total balance 8821.499927,
# day 28: buy 5 units at price 1422.250060, total balance 7399.249867
# day 29, sell 5 units at price 1470.449980, investment 411.123073 %, total balance 8869.699847,
# day 30, sell 5 units at price 1513.849945, investment 4.317117 %, total balance 10383.549792,
# day 36: buy 5 units at price 1420.899965, total balance 8962.649827
# day 37: buy 5 units at price 1432.400055, total balance 7530.249772
# day 38: buy 5 units at price 1422.700045, total balance 6107.549727
# day 39: buy 1 units at price 276.820007, total balance 5830.729720
# day 41: buy 5 units at price 1375.050050, total balance 4455.679670
# day 42: buy 5 units at price 1395.350035, total balance 3060.329635
# day 43: buy 5 units at price 1389.250030, total balance 1671.079605
# day 44: buy 5 units at price 1394.250030, total balance 276.829575
# day 53, sell 5 units at price 1588.300020, investment 460.503952 %, total balance 1865.129595,
# day 55, sell 5 units at price 1713.849945, investment 504.617935 %, total balance 3578.979540,
# day 57, sell 5 units at price 1788.600005, investment 25.304745 %, total balance 5367.579545,
# day 58, sell 5 units at price 1790.850065, investment 19.421845 %, total balance 7158.429610,
# day 59, sell 5 units at price 1854.149935, investment 30.367366 %, total balance 9012.579545,
# day 60, sell 5 units at price 1762.749940, investment 24.058694 %, total balance 10775.329485,
# day 61, sell 5 units at price 1811.100005, investment 26.438141 %, total balance 12586.429490,
# day 63: buy 5 units at price 1668.150025, total balance 10918.279465
# day 65, sell 5 units at price 1710.000000, investment 20.193994 %, total balance 12628.279465,
# day 66: buy 5 units at price 1722.500000, total balance 10905.779465
# day 67, sell 5 units at price 1749.649965, investment 532.053291 %, total balance 12655.429430,
# day 68: buy 5 units at price 1714.750060, total balance 10940.679370
# day 69, sell 5 units at price 1675.350035, investment 21.839204 %, total balance 12616.029405,
# day 70: buy 5 units at price 1554.299925, total balance 11061.729480
# day 71: buy 5 units at price 1545.800020, total balance 9515.929460
# day 72: buy 5 units at price 1544.499970, total balance 7971.429490
# day 73: buy 5 units at price 1592.550050, total balance 6378.879440
# day 74: buy 1 units at price 322.470001, total balance 6056.409439
# day 76: buy 5 units at price 1583.549955, total balance 4472.859484
# day 78, sell 5 units at price 1550.500030, investment 11.119073 %, total balance 6023.359514,
# day 79: buy 1 units at price 322.690002, total balance 5700.669512
# day 80: buy 1 units at price 323.850006, total balance 5376.819506
# day 84: buy 5 units at price 1487.149965, total balance 3889.669541
# day 86: buy 5 units at price 1533.249970, total balance 2356.419571
# day 87: buy 1 units at price 297.179993, total balance 2059.239578
# day 88: buy 1 units at price 290.170013, total balance 1769.069565
# day 91, sell 5 units at price 1747.700045, investment 25.801692 %, total balance 3516.769610,
# day 92, sell 5 units at price 1740.850065, investment 24.859245 %, total balance 5257.619675,
# day 93, sell 5 units at price 1709.949950, investment 2.505765 %, total balance 6967.569625,
# day 94, sell 5 units at price 1897.850035, investment 10.179973 %, total balance 8865.419660,
# day 95, sell 5 units at price 1851.699980, investment 7.986582 %, total balance 10717.119640,
# day 96, sell 5 units at price 1762.250060, investment 13.379022 %, total balance 12479.369700,
# day 97, sell 5 units at price 1777.449950, investment 14.985763 %, total balance 14256.819650,
# day 98, sell 3 units at price 1069.230012, investment -30.771769 %, total balance 15326.049662,
# day 101: buy 5 units at price 1677.250060, total balance 13648.799602
# day 102: buy 5 units at price 1527.500000, total balance 12121.299602
# day 103: buy 1 units at price 308.440002, total balance 11812.859600
# day 105, sell 5 units at price 1608.200075, investment 0.982702 %, total balance 13421.059675,
# day 106: buy 1 units at price 320.100006, total balance 13100.959669
# day 108, sell 5 units at price 1596.349945, investment 395.038280 %, total balance 14697.309614,
# day 109, sell 2 units at price 623.719970, investment -60.612549 %, total balance 15321.029584,
# day 125: buy 5 units at price 1491.649935, total balance 13829.379649
# day 126, sell 5 units at price 1495.500030, investment 0.258110 %, total balance 15324.879679,
# day 131: buy 5 units at price 1323.849945, total balance 14001.029734
# day 134: buy 5 units at price 1473.999940, total balance 12527.029794
# day 135: buy 1 units at price 281.829987, total balance 12245.199807
# day 136: buy 5 units at price 1309.750060, total balance 10935.449747
# day 137: buy 5 units at price 1252.799990, total balance 9682.649757
# day 138: buy 1 units at price 262.799988, total balance 9419.849769
# day 139: buy 5 units at price 1284.400025, total balance 8135.449744
# day 140: buy 5 units at price 1261.149980, total balance 6874.299764
# day 142: buy 5 units at price 1297.949980, total balance 5576.349784
# day 144: buy 5 units at price 1358.899995, total balance 4217.449789
# day 145: buy 5 units at price 1319.550020, total balance 2897.899769
# day 147: buy 5 units at price 1304.750060, total balance 1593.149709
# day 149: buy 5 units at price 1442.500000, total balance 150.649709
# day 150, sell 5 units at price 1574.299925, investment 18.918306 %, total balance 1724.949634,
# day 153, sell 5 units at price 1649.499970, investment 11.906380 %, total balance 3374.449604,
# day 155, sell 5 units at price 1721.399995, investment 510.793767 %, total balance 5095.849599,
# day 157, sell 5 units at price 1706.999970, investment 30.330207 %, total balance 6802.849569,
# day 158: buy 1 units at price 341.059998, total balance 6461.789571
# day 160: buy 1 units at price 351.399994, total balance 6110.389577
# day 161, sell 5 units at price 1752.550050, investment 39.890650 %, total balance 7862.939627,
# day 162, sell 5 units at price 1656.399995, investment 530.289220 %, total balance 9519.339622,
# day 163: buy 5 units at price 1693.650055, total balance 7825.689567
# day 166, sell 5 units at price 1771.549990, investment 37.928212 %, total balance 9597.239557,
# day 167, sell 5 units at price 1767.350005, investment 40.137972 %, total balance 11364.589562,
# day 168: buy 5 units at price 1737.449950, total balance 9627.139612
# day 169: buy 1 units at price 338.190002, total balance 9288.949610
# day 170: buy 5 units at price 1629.149935, total balance 7659.799675
# day 171, sell 5 units at price 1730.000000, investment 33.287109 %, total balance 9389.799675,
# day 172, sell 5 units at price 1719.600065, investment 26.543533 %, total balance 11109.399740,
# day 173, sell 5 units at price 1739.349975, investment 31.813872 %, total balance 12848.749715,
# day 177, sell 5 units at price 1798.500060, investment 37.842497 %, total balance 14647.249775,
# day 178, sell 5 units at price 1815.299990, investment 25.844020 %, total balance 16462.549765,
# day 179: buy 5 units at price 1789.850005, total balance 14672.699760
# day 183, sell 5 units at price 1883.950045, investment 452.380829 %, total balance 16556.649805,
# day 184, sell 5 units at price 1828.549955, investment 420.361408 %, total balance 18385.199760,
# day 185: buy 1 units at price 348.420013, total balance 18036.779747
# day 186: buy 5 units at price 1685.149995, total balance 16351.629752
# day 187: buy 1 units at price 332.970001, total balance 16018.659751
# day 188: buy 5 units at price 1576.900025, total balance 14441.759726
# day 189: buy 1 units at price 319.769989, total balance 14121.989737
# day 190: buy 5 units at price 1476.950075, total balance 12645.039662
# day 192: buy 1 units at price 316.130005, total balance 12328.909657
# day 193, sell 5 units at price 1669.349975, investment -1.434776 %, total balance 13998.259632,
# day 194, sell 5 units at price 1663.999940, investment -4.227460 %, total balance 15662.259572,
# day 195, sell 5 units at price 1550.599975, investment 358.499650 %, total balance 17212.859547,
# day 196: buy 1 units at price 300.359985, total balance 16912.499562
# day 199: buy 1 units at price 335.350006, total balance 16577.149556
# day 203: buy 1 units at price 334.399994, total balance 16242.749562
# day 204, sell 5 units at price 1722.149965, investment 5.708500 %, total balance 17964.899527,
# day 205, sell 5 units at price 1730.249940, investment -3.329892 %, total balance 19695.149467,
# day 206: buy 1 units at price 347.309998, total balance 19347.839469
# day 208: buy 5 units at price 1494.600065, total balance 17853.239404
# day 209: buy 5 units at price 1437.949980, total balance 16415.289424
# day 210, sell 5 units at price 1457.550050, investment 318.331323 %, total balance 17872.839474,
# day 211: buy 1 units at price 297.040009, total balance 17575.799465
# day 212: buy 5 units at price 1481.900025, total balance 16093.899440
# day 213: buy 1 units at price 297.459991, total balance 15796.439449
# day 214: buy 1 units at price 308.769989, total balance 15487.669460
# day 216, sell 5 units at price 1561.049955, investment -7.364332 %, total balance 17048.719415,
# day 217, sell 5 units at price 1564.450075, investment 369.847154 %, total balance 18613.169490,
# day 218: buy 5 units at price 1606.750030, total balance 17006.419460
# day 220, sell 5 units at price 1537.550050, investment -2.495401 %, total balance 18543.969510,
# day 221, sell 5 units at price 1528.999940, investment 378.156172 %, total balance 20072.969450,
# day 222, sell 1 units at price 312.839996, investment -78.818512 %, total balance 20385.809446,
# day 225: buy 1 units at price 303.769989, total balance 20082.039457
# day 226: buy 1 units at price 307.880005, total balance 19774.159452
# day 229: buy 5 units at price 1456.150055, total balance 18318.009397
# day 230: buy 5 units at price 1473.549955, total balance 16844.459442
# day 231: buy 1 units at price 298.769989, total balance 16545.689453
# day 233, sell 5 units at price 1573.699950, investment 397.801514 %, total balance 18119.389403,
# day 234, sell 5 units at price 1599.400025, investment 432.494375 %, total balance 19718.789428,
# day 235, sell 3 units at price 884.370027, investment 163.715524 %, total balance 20603.159455,
# day 238: buy 5 units at price 1381.199950, total balance 19221.959505
# day 239: buy 1 units at price 276.589996, total balance 18945.369509
# day 243: buy 1 units at price 288.959991, total balance 18656.409518
# day 244, sell 5 units at price 1449.799955, investment 333.552626 %, total balance 20106.209473,
# day 245, sell 2 units at price 550.859986, investment 58.607581 %, total balance 20657.069459,
# day 246: buy 1 units at price 269.489990, total balance 20387.579469
#
# total gained 10387.579469, total investment 103.875795 %
